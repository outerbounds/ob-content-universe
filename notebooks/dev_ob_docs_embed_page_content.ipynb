# %%
import os
from snowflake.sqlalchemy import URL
from sqlalchemy import create_engine
from dotenv import load_dotenv
import pandas as pd
import lancedb
from llama_index.core.schema import MetadataMode
from llama_index.core.node_parser import HTMLNodeParser
from llama_index.core import (
    Document,
    VectorStoreIndex,
    SimpleDirectoryReader,
    StorageContext,
)
from llama_index.vector_stores.lancedb import LanceDBVectorStore
# from transformers import MarkupLMFeatureExtractor, MarkupLMTokenizerFast, MarkupLMProcessor, MarkupLMModel, MarkupLMConfig
import html2text
from IPython.core.display import display, Markdown
# Out:
# /var/folders/rl/z6mhck6x3h1bl5bjmn0y3ws80000gn/T/ipykernel_45922/1151539119.py:18: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, Markdown

# %%
load_dotenv('../.env')
# Out:
# True

# %%
SNOWFLAKE_TABLE = 'DIM_DOCS_SITE_GA' 
SNOWFLAKE_SCHEMA = 'OB_DOCS_SITE_SCHEMA'

# %%
engine = create_engine(
    URL(
        user=os.environ["SNOWFLAKE_USER"],
        password=os.environ["SNOWFLAKE_PASSWORD"],
        account=os.environ["SNOWFLAKE_ACCOUNT_IDENTIFIER"],
        warehouse='google_analytics_wh',
        database=os.environ["SNOWFLAKE_DATABASE"],
        schema=SNOWFLAKE_SCHEMA,
        role=os.environ["SNOWFLAKE_OB_CONTENT_UNIVERSE_MF_TASK_ROLE"],
    )
)

# %%
df = pd.read_sql(f'SELECT * FROM {SNOWFLAKE_SCHEMA}.{SNOWFLAKE_TABLE}', engine)

# %%
df.sample(3)
# Out:
#                                         full_page_url  \
# 45  https://outerbounds.com/docs/debug-errors-with...
# 79  https://outerbounds.com/docs/intro-tutorial-S1E1/
# 82  https://outerbounds.com/docs/intro-tutorial-ov...
#
#           ga_query_start_date ga_query_end_date  \
# 45 2024-04-07 06:50:23.636465         yesterday
# 79 2024-04-07 06:50:23.636465         yesterday
# 82 2024-04-07 06:50:23.636465         yesterday
#
#                                               content  \
# 45  <main class="docMainContainer_gTbr"><div class...
# 79  <main class="docMainContainer_gTbr"><div class...
# 82  <main class="docMainContainer_gTbr"><div class...
#
#                                               title  \
# 45  Debug Metaflow Errors with Resume | Outerbounds
# 79                    Your First Flow | Outerbounds
# 82  Introduction to Metaflow Tutorial | Outerbounds
#
#                   scrape_date published_date  average_session_duration  \
# 45 2024-04-09 06:51:33.364070           None                  2.891434
# 79 2024-04-09 06:51:33.364070           None                 35.505272
# 82 2024-04-09 06:51:33.364070           None                  1.591639
#
#     stddev_average_session_duration  max_average_session_duration  \
# 45                         4.089104                      5.782867
# 79                        59.023406                    159.507853
# 82                         4.427878                     19.188963
#
#     avg_engagement_rate  avg_bounce_rate  sum_sessions
# 45             1.000000         0.000000             2
# 79             1.000000         0.000000             8
# 82             0.909091         0.090909            22

# %%
# filter out rows with no content
df = df[df['content'].notnull()]

# %%
# db = lancedb.connect("./.lancedb")
# db.create_table(LANCEDB_TABLENAME, data=df)
# db[LANCEDB_TABLENAME].head()

# %%
# h = html2text.HTML2Text()
# h.ignore_links = False
# # def _convert_html_to_markdown(html):
# #     return h.handle(example.content.values[0])
# example = df.sample(1)
# md = h.handle(example.content.values[0])
# display(Markdown(md))

# %%
# md_files = []
# for i, row in df.iterrows():
#     md_files.append(h.handle(row.content))

# %%
for _, row in df.iterrows():
    assert row.full_page_url is not None
    assert row.title is not None
    assert row.content is not None, row

# %%
documents = [
    Document(
        text=row.content,
        metadata={
            "full_page_url": row.full_page_url,
            "title": row.title
        },
        metadata_seperator="::",
        metadata_template="\n{key}=>{value}",
        text_template="Metadata: {metadata_str}\n-----\nContent: {content}"
    ) 
    for _, row in df.iterrows()
]
print(
    "The LLM sees this: \n\n\n",
    documents[0].get_content(metadata_mode=MetadataMode.LLM)[:200],
    "\n... [Truncated]"
)

print(
    "\n\n\nThe Embedding model sees this: \n",
    documents[0].get_content(metadata_mode=MetadataMode.EMBED)[:200],
    "\n... [Truncated]"
)
# Out:
# The LLM sees this:
#
#
#  Metadata: full_page_url=>https://outerbounds.com/docs/data-science-welcome/::
# title=>Metaflow Resources for Data Science | Outerbounds
# -----
# Content: <main class="docMainContainer_gTbr"><div class="co
# ... [Truncated]
#
#
#
# The Embedding model sees this:
#  Metadata: full_page_url=>https://outerbounds.com/docs/data-science-welcome/::
# title=>Metaflow Resources for Data Science | Outerbounds
# -----
# Content: <main class="docMainContainer_gTbr"><div class="co
# ... [Truncated]

# %%
parser = HTMLNodeParser()

# %%
nodes = parser.get_nodes_from_documents(documents)

# %%
len(documents), len(nodes)
# Out:
# (144, 2534)

# %%
vector_store = LanceDBVectorStore(uri="./.lancedb")
storage_context = StorageContext.from_defaults(vector_store=vector_store)
index = VectorStoreIndex(nodes, storage_context=storage_context)

# %%
index

# %%
query_engine = index.as_query_engine()

# %%
response = query_engine.query("How to deploy Outerbounds?")

# %%
response
# Out:
# Response(response='aws eks update-kubeconfig --name <cluster name> configure', source_nodes=[NodeWithScore(node=TextNode(id_='4e66ba17-2d1b-4171-acf8-716a95c0cf0e', embedding=[0.015595958568155766, 0.02286861464381218, 0.0021746333222836256, -0.01994863525032997, -0.01099767442792654, 0.016687538474798203, -0.04270809143781662, -0.02634802833199501, -0.029936598613858223, -0.015664182603359222, 0.013051210902631283, -0.0015572080155834556, -0.0075319064781069756, -0.013658402487635612, -0.01158439926803112, 0.005526126828044653, 0.01904808171093464, -0.021408624947071075, 0.0030496034305542707, -0.039433348923921585, -0.04191669449210167, 0.004366322420537472, 0.004004736430943012, -0.005607995670288801, -0.02692110650241375, 0.0005726534291170537, 0.004997392650693655, -0.03569468483328819, 0.004721086006611586, -0.016196327283978462, 0.018638739362359047, 0.011140944436192513, -0.022841325029730797, -0.015541379339993, -0.009831047616899014, -0.008568908087909222, 0.01408139057457447, -0.008159564808011055, 0.012546354904770851, -0.011325148865580559, 0.00655971746891737, 0.002575448015704751, -0.005427202675491571, -0.022554785013198853, -0.03050967864692211, 0.02578859217464924, 0.0028551656287163496, -0.023332536220550537, -0.025092709809541702, 0.02124488726258278, 0.007456860039383173, 0.025802237913012505, -0.039324190467596054, 0.03419376164674759, 0.0040797824040055275, -0.003307148115709424, -0.011802715249359608, 0.030727995559573174, 0.004489125218242407, -0.02487439289689064, 0.02415122091770172, -0.006041216664016247, -0.011359261348843575, -0.019866768270730972, -0.004697207827121019, -0.022213665768504143, -0.009496751241385937, 0.03967895731329918, -0.019525649026036263, -0.0168512761592865, 0.02033068984746933, 0.03891484811902046, -0.0028534599114209414, -0.02574765868484974, 0.019580228254199028, -0.02146320417523384, -0.011045431718230247, -0.0022633241023868322, 0.017915567383170128, 0.018761541694402695, -0.004953047260642052, -0.00716349808499217, 0.015964366495609283, 0.03400273621082306, 0.0026573166251182556, 0.005966170225292444, 0.0012681096559390426, 0.004199174232780933, 0.001170890755020082, 0.00047458172775804996, 0.006917892023921013, 0.012450841255486012, 0.03020949475467205, 0.009940206073224545, 0.007006583269685507, 0.001333775115199387, -0.017929211258888245, 0.009851515293121338, -0.009237500838935375, -0.0371137410402298, -0.030646126717329025, 0.015063812956213951, -0.01205514371395111, -0.01772454008460045, -0.028299227356910706, -0.01155028771609068, 0.026716435328125954, 0.00043620585347525775, 0.01805201545357704, -0.019512003287672997, -0.010854405350983143, 0.011065898463129997, -0.024901682510972023, -0.02726222574710846, -0.020985636860132217, -0.011256924830377102, 0.0032935035414993763, -0.03040052019059658, -0.003441890235990286, -0.01349466573446989, 0.010520108044147491, 0.03501245006918907, 0.016305485740303993, -0.021476848050951958, 0.003255980322137475, -0.004407256841659546, -0.02532467059791088, -0.03618589788675308, 0.00876675732433796, -0.035640109330415726, 0.03774140030145645, 0.02180432341992855, 0.008657598868012428, 0.0044754804112017155, -0.011304682120680809, 0.0192663986235857, -0.038341768085956573, 0.009824225679039955, -0.008712178096175194, -0.011775425635278225, 0.009974317625164986, 0.03755037486553192, 0.0041002496145665646, -0.007136208470910788, -0.013883541338145733, -0.0018505703192204237, -0.016196327283978462, 0.013426441699266434, 0.007900314405560493, -0.005161129869520664, -0.0035032916348427534, -0.020357979461550713, -0.019252752885222435, -0.007245366461575031, 0.025720369070768356, 0.0023793047294020653, 0.015145680867135525, -0.0006259532528929412, 0.027289515361189842, -0.029199782758951187, 0.02498355135321617, 0.02715306729078293, 0.000652816379442811, -0.007088451646268368, 0.024328602477908134, 0.027016621083021164, 0.0438542515039444, -0.029636414721608162, -0.014763628132641315, -0.018229397013783455, -0.006784855853766203, 0.01 ...

# %% [markdown]
# ### Resume with regular lanceDB

# %%
import lancedb
db = lancedb.connect("./.lancedb")

# %%
db['vectors'].head()
# Out:
# pyarrow.Table
# id: string
# doc_id: string
# vector: fixed_size_list<item: float>[1536]
#   child 0, item: float
# text: string
# metadata: struct<_node_content: string, _node_type: string, doc_id: string, document_id: string, full_page_url: string, ref_doc_id: string, title: string>
#   child 0, _node_content: string
#   child 1, _node_type: string
#   child 2, doc_id: string
#   child 3, document_id: string
#   child 4, full_page_url: string
#   child 5, ref_doc_id: string
#   child 6, title: string
# ----
# id: [["4e66ba17-2d1b-4171-acf8-716a95c0cf0e"],["0859c34b-51d8-4bf6-aad5-3e6eff5af145","84db4c0e-7591-44b7-9060-4b1661c9b70c","af222eac-85f9-4ad2-91ea-91dca46a8571","4fa868a1-0996-4371-adad-218325fb834f"]]
# doc_id: [["1c60f112-41d3-42cf-8d2d-5ef49bd4aa69"],["4e72869e-8942-492b-b0a0-7f47f49b8e77","4e72869e-8942-492b-b0a0-7f47f49b8e77","4e72869e-8942-492b-b0a0-7f47f49b8e77","4e72869e-8942-492b-b0a0-7f47f49b8e77"]]
# vector: [[[0.015595959,0.022868615,0.0021746333,-0.019948635,-0.010997674,...,-0.0045573493,0.006986116,-0.007218077,-0.027153067,-0.01949836]],[[0.0017149122,0.020055633,-0.015020509,-0.02012635,-0.009589365,...,-0.014242611,-0.0017423155,-0.001258781,-0.022997502,-0.034340676],[-0.001855108,0.004985384,-0.006987224,-0.027361969,-0.004608074,...,-0.013639061,0.0025188942,-0.0031023272,-0.021087442,-0.037535366],[0.002067383,0.019067055,-0.0126471,-0.022223474,-0.014261015,...,-0.014982278,-0.0027457988,0.00333852,-0.016610475,-0.030135944],[0.004297166,0.0139701525,0.004112154,-0.024184212,-0.007225941,...,-0.011938511,-0.0025779505,0.0031469497,-0.014026006,-0.037979826]]]
# text: [["<main class="docMainContainer_gTbr"><div class="container padding-top--md padding-bottom--lg"><div class="row"><div class="col docItemCol_VOVn"><div class="docItemContainer_Djhp"><article><div class="tocCollapsible_ETCw theme-doc-toc-mobile tocMobile_ITEo"><button class="clean-btn tocCollapsibleButton_TO0P" type="button">On this page</button></div><div class="theme-doc-markdown markdown"><header><h1>Deploying to AWS with Kubernetes</h1></header><p>This page shows how to deploy a complete <a href="/engineering/service-architecture/">Metaflow stack</a> powered by Kubernetes on AWS. For more information about the deployment, see <a href="/engineering/deployment/aws-k8s/details/">deployment details</a>, <a href="/engineering/deployment/aws-k8s/advanced/">advanced options</a> and <a href="/engineering/deployment/aws-k8s/faq/">FAQ</a>.</p><h2 class="anchor anchorWithStickyNavbar_LWe7" id="1-preparation">1. Preparation<a aria-label="Direct link to 1. Preparation" class="hash-link" href="#1-preparation" title="Direct link to 1. Preparation">​</a></h2><h3 class="anchor anchorWithStickyNavbar_LWe7" id="install-terraform">Install Terraform<a aria-label="Direct link to Install Terraform" class="hash-link" href="#install-terraform" title="Direct link to Install Terraform">​</a></h3><p><a href="https://www.terraform.io/" rel="noopener noreferrer" target="_blank">Terraform</a> is a popular infrastructure-as-code tool for managing cloud resources. We have published a set of terraform templates <a href="https://github.com/outerbounds/terraform-aws-metaflow" rel="noopener noreferrer" target="_blank">here</a> for setting up Metaflow on AWS. Terraform needs to be installed on your system in order to use these templates.</p><ol><li>Install terraform by following <a href="https://learn.hashicorp.com/tutorials/terraform/install-cli" rel="noopener noreferrer" target="_blank">these instructions</a>.</li><li>Download <a href="https://github.com/outerbounds/terraform-aws-metaflow" rel="noopener noreferrer" target="_blank">Metaflow on AWS terraform templates</a>:</li></ol><div class="codeBlockContainer_APcc theme-code-block" open="" style="--prism-color:#31302F;--prism-background-color:#FAF7F4"><div class="codeBlockContent_m3Ux"><pre class="prism-code language-text codeBlock_qGQc thin-scrollbar" tabindex="0"><code class="codeBlockLines_p187"><span class="token-line" style="color:#31302F"><span class="token plain">git clone git@github.com:outerbounds/terraform-aws-metaflow.git</span><br/></span></code></pre><div class="buttonGroup_6DOT"><button aria-label="Copy code to clipboard" class="clean-btn" title="Copy" type="button"><span aria-hidden="true" class="copyButtonIcons_eSgA"><svg class="copyButtonIcon_y97N" viewbox="0 0 24 24"><path d="M19,21H8V7H19M19,5H8A2,2 0 0,0 6,7V21A2,2 0 0,0 8,23H19A2,2 0 0,0 21,21V7A2,2 0 0,0 19,5M16,1H4A2,2 0 0,0 2,3V17H4V3H16V1Z"></path></svg><svg class="copyButtonSuccessIcon_LjdS" viewbox="0 0 24 24"><path d="M21,7L9,19L3.5,13.5L4.91,12.09L9,16.17L19.59,5.59L21,7Z"></path></svg></span></button></div></div></div><h3 class="anchor anchorWithStickyNavbar_LWe7" id="install-aws-cli">Install aws CLI<a aria-label="Direct link to Install aws CLI" class="hash-link" href="#install-aws-cli" title="Direct link to Install aws CLI">​</a></h3><p>This is the <a href="https://aws.amazon.com/cli/" rel="noopener noreferrer" target="_blank">official CLI tool ("aws")</a> published by Amazon for working with AWS. It will be used by Terraform when applying our templates (e.g. for authentication vs AWS). Please install it by following <a href="https://docs.aws.amazon.com/cli/latest/userguide/getting-started-install.html" rel="noopener noreferrer" target="_blank">these instructions</a>.</p><h3 class="anchor anchorWithStickyNavbar_LWe7" id="install-kubectl">Install kubectl<a aria-label="Direct link to Install kubectl" class="hash-link" href="#install-kubectl" title="Direct link to Install kubectl">​</a></h3><p><a href="https://kubernetes.io/ ...
# metadata: [
#   -- is_valid: all not null
#   -- child 0 type: string
# ["{"id_": "4e66ba17-2d1b-4171-acf8-716a95c0cf0e", "embedding": null, "metadata": {"full_page_url": "https://outerbounds.com/engineering/deployment/aws-k8s/deployment/", "title": "Deploying to AWS with Kubernetes | Outerbounds"}, "excluded_embed_metadata_keys": [], "excluded_llm_metadata_keys": [], "relationships": {"1": {"node_id": "1c60f112-41d3-42cf-8d2d-5ef49bd4aa69", "node_type": "4", "metadata": {"full_page_url": "https://outerbounds.com/engineering/deployment/aws-k8s/deployment/", "title": "Deploying to AWS with Kubernetes | Outerbounds"}, "hash": "2724d416f2480a94deef8fa038a487c63a2f460ef57b028b757b881704f6446f", "class_name": "RelatedNodeInfo"}}, "text": "<main class=\"docMainContainer_gTbr\"><div class=\"container padding-top--md padding-bottom--lg\"><div class=\"row\"><div class=\"col docItemCol_VOVn\"><div class=\"docItemContainer_Djhp\"><article><div class=\"tocCollapsible_ETCw theme-doc-toc-mobile tocMobile_ITEo\"><button class=\"clean-btn tocCollapsibleButton_TO0P\" type=\"button\">On this page</button></div><div class=\"theme-doc-markdown markdown\"><header><h1>Deploying to AWS with Kubernetes</h1></header><p>This page shows how to deploy a complete <a href=\"/engineering/service-architecture/\">Metaflow stack</a> powered by Kubernetes on AWS. For more information about the deployment, see <a href=\"/engineering/deployment/aws-k8s/details/\">deployment details</a>, <a href=\"/engineering/deployment/aws-k8s/advanced/\">advanced options</a> and <a href=\"/engineering/deployment/aws-k8s/faq/\">FAQ</a>.</p><h2 class=\"anchor anchorWithStickyNavbar_LWe7\" id=\"1-preparation\">1. Preparation<a aria-label=\"Direct link to 1. Preparation\" class=\"hash-link\" href=\"#1-preparation\" title=\"Direct link to 1. Preparation\">\u200b</a></h2><h3 class=\"anchor anchorWithStickyNavbar_LWe7\" id=\"install-terraform\">Install Terraform<a aria-label=\"Direct link to Install Terraform\" class=\"hash-link\" href=\"#install-terraform\" title=\"Direct link to Install Terraform\">\u200b</a></h3><p><a href=\"https://www.terraform.io/\" rel=\"noopener noreferrer\" target=\"_blank\">Terraform</a> is a popular infrastructure-as-code tool for managing cloud resources. We have published a set of terraform templates <a href=\"https://github.com/outerbounds/terraform-aws-metaflow\" rel=\"noopener noreferrer\" target=\"_blank\">here</a> for setting up Metaflow on AWS. Terraform needs to be installed on your system in order to use these templates.</p><ol><li>Install terraform by following <a href=\"https://learn.hashicorp.com/tutorials/terraform/install-cli\" rel=\"noopener noreferrer\" target=\"_blank\">these instructions</a>.</li><li>Download <a href=\"https://github.com/outerbounds/terraform-aws-metaflow\" rel=\"noopener noreferrer\" target=\"_blank\">Metaflow on AWS terraform templates</a>:</li></ol><div class=\"codeBlockContainer_APcc theme-code-block\" open=\"\" style=\"--prism-color:#31302F;--prism-background-color:#FAF7F4\"><div class=\"codeBlockContent_m3Ux\"><pre class=\"prism-code language-text codeBlock_qGQc thin-scrollbar\" tabindex=\"0\"><code class=\"codeBlockLines_p187\"><span class=\"token-line\" style=\"color:#31302F\"><span class=\"token plain\">git clone git@github.com:outerbounds/terraform-aws-metaflow.git</span><br/></span></code></pre><div class=\"buttonGroup_6DOT\"><button aria-label=\"Copy code to clipboard\" class=\"clean-btn\" title=\"Copy\" type=\"button\"><span aria-hidden=\"true\" class=\"copyButtonIcons_eSgA\"><svg class=\"copyButtonIcon_y97N\" viewbox=\"0 0 24 24\"><path d=\"M19,21H8V7H19M19,5H8A2,2 0 0,0 6,7V21A2,2 0 0,0 8,23H19A2,2 0 0,0 21,21V7A2,2 0 0,0 19,5M16,1H4A2,2 0 0,0 2,3V17H4V3H16V1Z\"></path></svg><svg class=\"copyButtonSuccessIcon_LjdS\" viewbox=\"0 0 24 24\"><path d=\"M21,7L9,19L3.5,13.5L4.91,12.09L9,16.17L19.59,5.59L21,7Z\"></path></svg></span></button></div></div></div><h3 class=\"anchor anchorWithStickyNavbar_LWe7\" id=\"install-aws-cli\">Install aws CLI<a aria-label=\"Direct link to Install aws ...
#   -- child 1 type: string
# ["TextNode"]
#   -- child 2 type: string
# ["1c60f112-41d3-42cf-8d2d-5ef49bd4aa69"]
#   -- child 3 type: string
# ["1c60f112-41d3-42cf-8d2d-5ef49bd4aa69"]
#   -- child 4 type: string
# ["https://outerbounds.com/engineering/deployment/aws-k8s/deployment/"]
#   -- child 5 type: string
# ["1c60f112-41d3-42cf-8d2d-5ef49bd4aa69"]
#   -- child 6 type: string
# ["Deploying to AWS with Kubernetes | Outerbounds"],
#   -- is_valid: all not null
#   -- child 0 type: string
# ["{"id_": "0859c34b-51d8-4bf6-aad5-3e6eff5af145", "embedding": null, "metadata": {"tag": "h1", "full_page_url": "https://outerbounds.com/docs/data-science-welcome/", "title": "Metaflow Resources for Data Science | Outerbounds"}, "excluded_embed_metadata_keys": [], "excluded_llm_metadata_keys": [], "relationships": {"1": {"node_id": "4e72869e-8942-492b-b0a0-7f47f49b8e77", "node_type": "4", "metadata": {"full_page_url": "https://outerbounds.com/docs/data-science-welcome/", "title": "Metaflow Resources for Data Science | Outerbounds"}, "hash": "20dd87b89f0a3a5e6a177e67b618376f8d5a1ca244f50312a1deea515a9ef6eb", "class_name": "RelatedNodeInfo"}, "3": {"node_id": "84db4c0e-7591-44b7-9060-4b1661c9b70c", "node_type": "1", "metadata": {"tag": "p"}, "hash": "1d49331e3c26623a44184b375800ac5af7608d81b82182386581c908c8cfe1a8", "class_name": "RelatedNodeInfo"}}, "text": "Metaflow Resources for Data Science", "start_char_idx": 241, "end_char_idx": 276, "text_template": "Metadata: {metadata_str}\n-----\nContent: {content}", "metadata_template": "\n{key}=>{value}", "metadata_seperator": "::", "class_name": "TextNode"}","{"id_": "84db4c0e-7591-44b7-9060-4b1661c9b70c", "embedding": null, "metadata": {"tag": "p", "full_page_url": "https://outerbounds.com/docs/data-science-welcome/", "title": "Metaflow Resources for Data Science | Outerbounds"}, "excluded_embed_metadata_keys": [], "excluded_llm_metadata_keys": [], "relationships": {"1": {"node_id": "4e72869e-8942-492b-b0a0-7f47f49b8e77", "node_type": "4", "metadata": {"full_page_url": "https://outerbounds.com/docs/data-science-welcome/", "title": "Metaflow Resources for Data Science | Outerbounds"}, "hash": "20dd87b89f0a3a5e6a177e67b618376f8d5a1ca244f50312a1deea515a9ef6eb", "class_name": "RelatedNodeInfo"}, "2": {"node_id": "0859c34b-51d8-4bf6-aad5-3e6eff5af145", "node_type": "1", "metadata": {"tag": "h1", "full_page_url": "https://outerbounds.com/docs/data-science-welcome/", "title": "Metaflow Resources for Data Science | Outerbounds"}, "hash": "95bdd7ac646fe1098ac74245e52b4fb79726b9f8d1b2a04af0b6741235aaa17d", "class_name": "RelatedNodeInfo"}, "3": {"node_id": "af222eac-85f9-4ad2-91ea-91dca46a8571", "node_type": "1", "metadata": {"tag": "h5"}, "hash": "b8374f37a0d4275116cb6740b4f0bdab85538a1a410493e9e44e892ee915e267", "class_name": "RelatedNodeInfo"}}, "text": "Building end-to-end ML-powered applications isn't straightforward. These resources are here to unblock, spark ideas, and help your team get the most out of Metaflow.", "start_char_idx": 293, "end_char_idx": 458, "text_template": "Metadata: {metadata_str}\n-----\nContent: {content}", "metadata_template": "\n{key}=>{value}", "metadata_seperator": "::", "class_name": "TextNode"}","{"id_": "af222eac-85f9-4ad2-91ea-91dca46a8571", "embedding": null, "metadata": {"tag": "h5", "full_page_url": "https://outerbounds.com/docs/data-science-welcome/", "title": "Metaflow Resources for Data Science | Outerbounds"}, "excluded_embed_metadata_keys": [], "excluded_llm_metadata_keys": [], "relationships": {"1": {"node_id": "4e72869e-8942-492b-b0a0-7f47f49b8e77", "node_type": "4", "metadata": {"full_page_url": "https://outerbounds.com/docs/data-science-welcome/", "title": "Metaflow Resources for Data Science | Outerbounds"}, "hash": "20dd87b89f0a3a5e6a177e67b618376f8d5a1ca244f50312a1deea515a9ef6eb", "class_name": "RelatedNodeInfo"}, "2": {"node_id": "84db4c0e-7591-44b7-9060-4b1661c9b70c", "node_type": "1", "metadata": {"tag": "p", "full_page_url": "https://outerbounds.com/docs/data-science-welcome/", "title": "Metaflow Resources for Data Science | Outerbounds"}, "hash": "1808337bfa650d5086890e0cbd2188fab10ffce0578374ce55fa8709e0703ba2", "class_name": "RelatedNodeInfo"}, "3": {"node_id": "4fa868a1-0996-4371-adad-218325fb834f", "node_type": "1", "metadata": {"tag": "p"}, "hash": "d4a5cc6e11cdd2a9bdd59bc3ba3fd8533e81037bc4dd0e7a0998dfdcea18dbf6", "class_name": "RelatedNodeInfo"}}, "text": "Full Stack", "start_char_idx": 652, "end_char_idx": 662, "text_template": ...
#   -- child 1 type: string
# ["TextNode","TextNode","TextNode","TextNode"]
#   -- child 2 type: string
# ["4e72869e-8942-492b-b0a0-7f47f49b8e77","4e72869e-8942-492b-b0a0-7f47f49b8e77","4e72869e-8942-492b-b0a0-7f47f49b8e77","4e72869e-8942-492b-b0a0-7f47f49b8e77"]
#   -- child 3 type: string
# ["4e72869e-8942-492b-b0a0-7f47f49b8e77","4e72869e-8942-492b-b0a0-7f47f49b8e77","4e72869e-8942-492b-b0a0-7f47f49b8e77","4e72869e-8942-492b-b0a0-7f47f49b8e77"]
#   -- child 4 type: string
# ["https://outerbounds.com/docs/data-science-welcome/","https://outerbounds.com/docs/data-science-welcome/","https://outerbounds.com/docs/data-science-welcome/","https://outerbounds.com/docs/data-science-welcome/"]
#   -- child 5 type: string
# ["4e72869e-8942-492b-b0a0-7f47f49b8e77","4e72869e-8942-492b-b0a0-7f47f49b8e77","4e72869e-8942-492b-b0a0-7f47f49b8e77","4e72869e-8942-492b-b0a0-7f47f49b8e77"]
#   -- child 6 type: string
# ["Metaflow Resources for Data Science | Outerbounds","Metaflow Resources for Data Science | Outerbounds","Metaflow Resources for Data Science | Outerbounds","Metaflow Resources for Data Science | Outerbounds"]]

# %% [markdown]
# ### MarkupLM experiment

# %%
feature_extractor = MarkupLMFeatureExtractor()
tokenizer = MarkupLMTokenizerFast.from_pretrained("microsoft/markuplm-base")
processor = MarkupLMProcessor(feature_extractor, tokenizer)

# %%
html_string = df.sample(1)['content'].values[0]
encoding = processor(html_string, return_tensors="pt")

# %%
print(encoding.keys())
# Out:
# dict_keys(['input_ids', 'token_type_ids', 'attention_mask', 'xpath_tags_seq', 'xpath_subs_seq'])

# %%
type(encoding), len(encoding)
# Out:
# (transformers.tokenization_utils_base.BatchEncoding, 5)

# %%
encoding.items()
# Out:
# dict_items([('input_ids', tensor([[   0, 4148,   42,  ...,  110, 3041,    2]])), ('token_type_ids', tensor([[0, 0, 0,  ..., 0, 0, 0]])), ('attention_mask', tensor([[1, 1, 1,  ..., 1, 1, 1]])), ('xpath_tags_seq', tensor([[[216, 216, 216,  ..., 216, 216, 216],
#          [124,  50,  50,  ..., 216, 216, 216],
#          [124,  50,  50,  ..., 216, 216, 216],
#          ...,
#          [124,  50,  50,  ..., 216, 216, 216],
#          [124,  50,  50,  ..., 216, 216, 216],
#          [216, 216, 216,  ..., 216, 216, 216]]])), ('xpath_subs_seq', tensor([[[1001, 1001, 1001,  ..., 1001, 1001, 1001],
#          [   0,    0,    0,  ..., 1001, 1001, 1001],
#          [   0,    0,    0,  ..., 1001, 1001, 1001],
#          ...,
#          [   0,    0,    0,  ..., 1001, 1001, 1001],
#          [   0,    0,    0,  ..., 1001, 1001, 1001],
#          [1001, 1001, 1001,  ..., 1001, 1001, 1001]]]))])

# %%
configuration = MarkupLMConfig()
model = MarkupLMModel(configuration)

# %%
# encoding = processor("<html> <head> <title>Page Title</title> </head> </html>", return_tensors="pt")
# outputs = model(**encoding)

# %%
encoding
# Out:
# {'input_ids': tensor([[    0, 21823, 13497,     2]]), 'token_type_ids': tensor([[0, 0, 0, 0]]), 'attention_mask': tensor([[1, 1, 1, 1]]), 'xpath_tags_seq': tensor([[[216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216,
#           216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216,
#           216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216,
#           216, 216, 216, 216, 216, 216, 216, 216],
#          [109, 104, 200, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216,
#           216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216,
#           216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216,
#           216, 216, 216, 216, 216, 216, 216, 216],
#          [109, 104, 200, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216,
#           216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216,
#           216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216,
#           216, 216, 216, 216, 216, 216, 216, 216],
#          [216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216,
#           216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216,
#           216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216, 216,
#           216, 216, 216, 216, 216, 216, 216, 216]]]), 'xpath_subs_seq': tensor([[[1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001,
#           1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001,
#           1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001,
#           1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001,
#           1001, 1001, 1001, 1001, 1001, 1001],
#          [   0,    0,    0, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001,
#           1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001,
#           1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001,
#           1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001,
#           1001, 1001, 1001, 1001, 1001, 1001],
#          [   0,    0,    0, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001,
#           1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001,
#           1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001,
#           1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001,
#           1001, 1001, 1001, 1001, 1001, 1001],
#          [1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001,
#           1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001,
#           1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001,
#           1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001, 1001,
#           1001, 1001, 1001, 1001, 1001, 1001]]])}

# %%
enc = processor(html_string, return_tensors="pt")
enc.input_ids.shape, enc.attention_mask.shape, enc.token_type_ids.shape, enc.xpath_tags_seq.shape, enc.xpath_subs_seq.shape
# Out:
# (torch.Size([1, 5135]),
#  torch.Size([1, 5135]),
#  torch.Size([1, 5135]),
#  torch.Size([1, 5135, 50]),
#  torch.Size([1, 5135, 50]))

# %%
enc_demo = processor("<html> <head> <title>Page Title</title> </head> </html>", return_tensors="pt")

# %%
enc_demo.input_ids.shape, enc_demo.attention_mask.shape, enc_demo.token_type_ids.shape, enc_demo.xpath_tags_seq.shape, enc_demo.xpath_subs_seq.shape
# Out:
# (torch.Size([1, 4]),
#  torch.Size([1, 4]),
#  torch.Size([1, 4]),
#  torch.Size([1, 4, 50]),
#  torch.Size([1, 4, 50]))

# %%
enc_demo.keys()
# Out:
# dict_keys(['input_ids', 'token_type_ids', 'attention_mask', 'xpath_tags_seq', 'xpath_subs_seq'])
