# %%
import xml.etree.ElementTree as ET
import time

import requests
from bs4 import BeautifulSoup
import pandas as pd
from selenium import webdriver
from tqdm import tqdm

from langchain_community.document_loaders import WebBaseLoader

# %%
URL = "https://outerbounds.com/blog"

# %%
# Setup the WebDriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')  # Runs Chrome in headless mode.
driver = webdriver.Chrome(options=options)

# Open the webpage
driver.get(URL)

# Function to scroll the page in increments
def incremental_scroll(n=25):
    last_height = driver.execute_script("return document.body.scrollHeight")
    while True:
        # Scroll down by a third of the page height
        scroll_height = driver.execute_script("return document.body.scrollHeight") / n
        for i in range(n):  # Split the scroll into three increments
            driver.execute_script(f"window.scrollBy(0, {scroll_height});")
            time.sleep(1/n)  # Wait after each increment
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break  # Exit the loop if the scroll height hasn't changed after the scroll
        last_height = new_height

# Use the function to scroll incrementally
incremental_scroll()

# Parse page source with BeautifulSoup
soup = BeautifulSoup(driver.page_source, 'html.parser')
articles = soup.find_all('article')

# Process your articles here
for article in articles:
    print(article.text)  # Or any processing you need

driver.quit()
# Out:
# Free Live Courses: Full-Stack Machine Learning and Building Systems with LLMsJoin Hugo Bowne-Anderson for two live courses on building full-stack machine learning systems.March 28, 2024  · 3 min readThe Outerbounds Team
# New in Outerbounds: Access NVIDIA Cloud GPUsYou can now apply to access cloud GPUs directly in NVIDIA's DGX Cloud through Outerbounds - just add @nvidia to access GPUs at scale!March 18, 2024  · 4 min readThe Outerbounds Team
# Develop ML/AI systems easily on all cloudsOuterbounds is now available on all cloud marketplaces. Learn why and how to develop ML/AI systems quickly without cloud lock-in.March 15, 2024  · 9 min readThe Outerbounds Team
# Spring Tour 2024Outerbounds is going global in 2024. This page shows our event calendar for spring 2024.March 12, 2024  · 5 min readThe Outerbounds Team
# The 6 Steps to Cost-Optimized ML/AI/Data WorkloadsWe share a six-step process for understanding cloud costs, attributing, and minimizing them. The process is conveniently integrated in the Outerbounds platform.February 24, 2024  · 10 min readThe Outerbounds Team
# The Many Ways to Deploy a ModelThere are many ways to deploy models and perform inference. Here, we share our decision rubric for model deployments using LLM inference as an example.February 6, 2024  · 13 min readHamel HusainThe Outerbounds Team
# Generative AI Workflows, Compute, HPC, and Metaflow at PyData GlobalMetaflow and Outerbounds were at PyData Global! We hosted sessions on full stack ML and emphasized discussions on the evolution of the compute layer of the ML stack. This post organizes the presentations in a quick choose-your-own-adventure read.February 6, 2024  · 8 min readThe Outerbounds Team
# Metaflow 2.11: Building Observable ML/AI SystemsMake ML/AI systems observable with new Metaflow Dynamic Cards that provide real-time visualizations.January 19, 2024  · 8 min readThe Outerbounds Team
# Develop ML and AI with Metaflow, Deploy with NVIDIA Triton Inference ServerLearn how Outerbounds and NVIDIA are collaborating to provide an end-to-end system for developing, scaling, deploying, and improving AI systems.January 8, 2024  · 14 min readThe Outerbounds Team
# Lights, GenAI, Action: Building Systems with Generative VideoHow to run massively parallel Stable Video Diffusion for production use cases, producing new images and videos automatically in a highly-available manner.December 12, 2023  · 10 min readThe Outerbounds Team
# Making Large Language Models Uncool AgainWe sat down with Jeremy Howard, the creator of fast.ai, to discuss the rapidly evolving AI landscape.December 1, 2023  · 13 min readThe Outerbounds Team
# AI & ML from the Trenches: Adept.ai, Autodesk, and Epignosis – Massive Compute and GenAIA summary of recent talks from enterprises building machine learning platforms with Metaflow.November 28, 2023  · 10 min readThe Outerbounds Team
# New in Metaflow: Train at scale with AI/ML frameworksToday, we release support for distributed training and other high-performance computing workloads in Metaflow, powered by popular open-source frameworks like Ray, Torch, Deepspeed, Tensorflow and MPI, introduced in this article.November 6, 2023  · 12 min readThe Outerbounds Team
# Compute Anything with MetaflowToday, we release support for cost-efficient distributed training and other high-performance computing workloads in Metaflow. Read this post for the backstory.November 6, 2023  · 9 min readThe Outerbounds Team
# LLMs, RAG, and Fine-Tuning: A Hands-On Guided TourA hands-on guided tour to LLMs, prompt engineering, retrieval-augmented generation, and building ML systems in the Metaflow Sandbox.November 2, 2023  · 7 min readThe Outerbounds Team
# Outerbounds at KubeCon NA 2023We’re excited to be in Chicago later this month for KubeCon North America.October 19, 2023  · 4 min readThe Outerbounds Team
# AI & ML From the Trenches: Amazon Prime, DTN, and Realtor.comA summary of recent talks from enterprises building machine learning platforms with Metaflow.October 17, 2023  · 10 min readThe Outerbounds Team
# New in Metaflow: The Long-Awaited @pypi DecoratorYou can now install dependencies from PyPI as well as Conda in your Metaflow steps.October 5, 2023  · 7 min readThe Outerbounds Team
# AI & ML From the Trenches: DeliveryHero, Ramp, and DellA summary of recent talks from enterprises building machine learning platforms with Metaflow.September 21, 2023  · 7 min readThe Outerbounds Team
# Better, Faster, Stronger LLM Fine-tuningReactive, configurable, cheaper LLM fine-tuning with MetaflowSeptember 8, 2023  · 8 min readValay DaveUtkarsh Kashyap
# Retrieval-Augmented Generation: How to Use Your Data to Guide LLMsLearn how to use Retrieval Augmented Generation to control hallucinations and get more relevant responses from LLMs.August 24, 2023  · 13 min readFederico BianchiEddie Mattia
# Seamless Data and ML Pipelines with Airflow and MetaflowLearn how to develop ML, AI, and data science with Metaflow, deploy alongside existing data pipelines on Airflow.August 10, 2023  · 9 min readMichael GregoryValay Dave
# Secure ML with Secure Software DependenciesEngineers from Chainguard and Outerbunds discuss their common philosophy around security and machine learning workflows.July 27, 2023  · 9 min readZack NewmanSavin Goyal
# Announcing 4 New Features in the Outerbounds Platform: Cloud Workstations and MoreExplore four major new features in the Outerbounds PlatformJuly 19, 2023  · 10 min readThe Outerbounds Team
# Learn Full-Stack Machine Learning: Batteries IncludedLearn how you can get started with full-stack ML today in a hands-on, project-driven course using production-grade ML systems.July 10, 2023  · 7 min readHugo Bowne-AndersonVille Tuulos
# Fine-tuning a Large Language Model using Metaflow, featuring LLaMA and LoRAA workflow template built with Metaflow for fine-tuning LLMs for custom use cases.June 21, 2023  · 16 min readFederico BianchiThe Outerbounds Team
# Large Language Models and the Future of Custom, Fine-tuned LLMsAn overview of instruction tuning for large language models using the LLaMA family of models.June 21, 2023  · 16 min readFederico BianchiThe Outerbounds Team
# The Open-Source Modern Data Stack featuring Apache IcebergWe sat down with Jason Reid, a Co-founder at Tabular, to discuss the Apache Iceberg project and how it fits into the modern data stack.June 14, 2023  · 10 min readJason ReidHugo Bowne-Anderson
# New in Metaflow: Accessing Secrets SecurelyYou can now access secrets securely in Metaflow flows using the new secrets decorator.June 2, 2023  · 4 min readThe Outerbounds Team
# Metaflow 2.9: Building Reactive Machine Learning Systems with Event TriggeringUsing the new event triggering feature in Metaflow, you can compose systems using workflows as building blocks and trigger them based on external events.May 17, 2023  · 8 min readThe Outerbounds Team
# Large Language Models, Business Value, and RiskAn interview with Federico Bianchi, a postdoctoral NLP researcher at Stanford exploring the boundaries of large language models.May 11, 2023  · 15 min readFederico BianchiHugo Bowne-Anderson
# Fast Data: Loading Tables From S3 At Lightning SpeedLoad and process tabular data at lightning speed using Apache Arrow and Metaflow.May 5, 2023  · 11 min readThe Outerbounds Team
# Case Study: How Realtor.com uses MetaflowWe sat down with Russell Brooks, Principal ML Engineer at Realtor.com, to discuss how his team uses Metaflow, and how it impacts Realtor.com.April 26, 2023  · 12 min readRussell BrooksHugo Bowne-Anderson
# Training a Large Language Model With Metaflow, Featuring DollyWe use Metaflow to train Dolly, to show an example of fine-tuning LLMs and what it takes to use these models in practice.April 20, 2023  · 12 min readThe Outerbounds Team
# Large Language Models and the Future of the ML Infrastructure StackA peek into how Outerbounds views the ongoing evolution of the machine learning stack, in the wake of recent LLM waves.April 19, 2023  · 8 min readThe Outerbounds Team
# Announcing the Metaflow Card ViewerSharing results of your ML experiments with colleagues has never been easier with the Metaflow card viewer. Use it from your sandbox today!April 13, 2023  · 2 min readThe Outerbounds Team
# Whisper with Metaflow on KubernetesHow to run and optimize OpenAI's Whisper model on a state-of-the-art Kubernetes cluster powered by Metaflow.March 28, 2023  · 11 min readShri Javadekar
# Learn Machine Learning and AI Infrastructure in the BrowserMetaflow Sandboxes are now loaded with many new interactive ML tutorials: learn about cutting-edge AI and ML, right in your browser.March 14, 2023  · 3 min readThe Outerbounds Team
# How MoneyLion Customized MetaflowAn interview with Yudhiesh Ravindranath, an MLOps Engineer at MoneyLion, detailing the extensions their team has built on top of Metaflow.March 8, 2023  · 9 min readYudhiesh RavindranathHugo Bowne-Anderson
# Better Airflow with MetaflowYou can now orchestrate workflows developed with Metaflow on Apache Airflow.February 21, 2023  · 8 min readThe Outerbounds Team
# Announcing The Outerbounds PlatformOuterbounds Platform is now generally available! Get started with a managed platform for data and ML workloads that operates seamlessly with open-source Metaflow.January 31, 2023  · 9 min readThe Outerbounds Team
# Event: How to Build a Full-Stack Recommender SystemJoin Jacopo Tagliabue and Hugo Bowne-Anderson in a live code along session to dive into how to build a production-grade recommender system.January 20, 2023  · One min readThe Outerbounds Team
# Case Study: MLOps for FinTech using MetaflowYudhiesh Ravindranath, an MLOps Engineer at MoneyLion, discusses how his team builds and maintains an MLOps stack at a FinTech company.January 12, 2023  · 8 min readYudhiesh RavindranathHugo Bowne-Anderson
# Full Stack Machine Learning, ML Engineering, and SWE Skills for Data ScienceEthan Rosenthal joins Hugo to discuss how you can build your career and the layers of a full machine learning stack in your organization.December 16, 2022  · 15 min readThe Outerbounds Team
# Metaflow Now Supports All the Major Clouds: Google Cloud, Azure, and AWSMetaflow can now be used equally across Google Cloud, Azure, or AWS without any changes in user code or workflows.December 13, 2022  · 7 min readThe Outerbounds Team
# The Moving Parts of the Full Machine Learning Stack and Building ML PlatformsRussell Brooks joins Hugo to discuss how you can build a valuable machine learning team and tech stack in your organization.November 29, 2022  · 15 min readThe Outerbounds Team
# Case Study: MLOps for NLP-powered Media Intelligence using MetaflowAn interview with Jules Belveze, an MLOps Engineer at Hypefactors where they apply NLP and AI for media intelligence.November 17, 2022  · 7 min readHugo Bowne-AndersonJules Belveze
# The 4 Main Tasks in the Production ML Lifecycle, MLOps, and Data-centric AIA recap of a chat with Shreya Shankar about her paper, Operationalizing Machine Learning: Patterns and Pain Points from MLOps Practitioners.November 3, 2022  · 14 min readThe Outerbounds Team
# Event: How to Build an Enterprise Machine Learning Platform from ScratchA conversation with Russell Brooks and Hugo Bowne-Anderson on the journey to reproducible and automated ML-powered software.October 31, 2022  · 2 min readThe Outerbounds Team
# MLOps for Foundation Models: Whisper and MetaflowWe show how to use large models like Whisper in a production-grade workflow by applying MLOps practices with Metaflow.October 21, 2022  · 15 min readEddie Mattia
# Now Available: Machine Learning with Metaflow on AzureMetaflow on Azure provides one of the most user-friendly machine learning experiences on Azure, both for data scientists as well as engineers.October 6, 2022  · 5 min readThe Outerbounds Team
# Ask Me Anything: Machine Learning Infrastructure for HumansA collection of responses from an AMA event where Chip Huyen and Ville Tuulos addressed questions about machine learning infrastructure.September 29, 2022  · 12 min readThe Outerbounds Team
# Event: Patterns and Pain Points from MLOps PractitionersShreya Shankar joins Hugo Bowne-Anderson to discuss her team’s recent paper Operationalizing Machine Learning: An Interview Study.September 27, 2022  · 2 min readThe Outerbounds Team
# Applying the Practical Machine Learning Infrastructure StackHow can you leverage modern tools to apply a state-of-the-art machine learning infrastructure stack in practice?September 23, 2022  · 4 min readVille TuulosHugo Bowne-Anderson
# Announcing Metaflow Sandboxes: Free Data Science Infrastructure in the BrowserUse new Metaflow Sandboxes to evaluate Metaflow and the full infrastructure stack behind it in the browser without having to install anything locallySeptember 16, 2022  · 3 min readThe Outerbounds Team
# Parallelizing Stable Diffusion for Production Use CasesHow to run massively parallel Stable Diffusion for production use cases, producing new images automatically in a highly-available manner.September 8, 2022  · 9 min readValay DaveHugo Bowne-Anderson
# Event: Machine Learning + Infrastructure for HumansA book launch event including a discussion with authors Chip Huyen and Ville Tuulos about machine learning education and practice.September 6, 2022  · 2 min readThe Outerbounds Team
# Book Launch: Effective Data Science InfrastructureBy reading a new book, Effective Data Science Infrastructure, you will learn how to set up infrastructure for ML and data science applications, similar to the stack that powers Netflix and hundreds of other modern companies.August 30, 2022  · 8 min readVille Tuulos
# DataOps and MLOps for Reasonable OrganizationsHow to combine DataOps and MLOps to produce business value: good machine learning tools provide a better way to think about the division of work and culture.August 16, 2022  · 7 min readJacopo TagliabueHugo Bowne-Anderson
# Testable Technical Documentation with Notebooks, nbdev, and DocusaurusLearn how you can streamline authoring, testing and maintenance of technical documentation with Jupyter Notebooks, nbdev and Docusaurus.August 2, 2022  · 8 min readThe Outerbounds Team
# Machine Learning with the Modern Data Stack: A Case StudyLeveraging the Modern Data Stack for Machine Learning: how to combine DataOps and MLOps to produce business value.July 28, 2022  · 9 min readJacopo TagliabueHugo Bowne-Anderson
# 5 Ways to Use the New Metaflow TagsWe are happy to announce support for mutable tags in Metaflow! Learn five key patterns for effective human-in-the-loop workflows which leverage the new feature.June 21, 2022  · 6 min readJackie TungVille Tuulos
# Developing Scalable Feature Engineering DAGsDiscover the power of DAGs to level up your data science projects with examples from feature transforms to workflow orchestration.June 16, 2022  · 11 min readEddie MattiaStefan Krawczyk
# Introducing Metaflow Resources for Data Science and EngineeringA knowledge base of free, practical data science and machine learning materials, including how to set up a modern data science infrastructure.May 31, 2022  · 6 min readThe Outerbounds Team
# The Modern Stack of ML InfrastructureA discussion about the machine learning deployment stack and why data makes software different.May 2, 2022  · 9 min readVille TuulosHugo Bowne-Anderson
# Human-Centric Data Science on Kubernetes with MetaflowData scientists can now scale out their machine learning workflows to Kubernetes clusters using Metaflow and Argo, without needing to know the ins and outs of K8S.April 25, 2022  · 8 min readSavin Goyal
# Fireside chat #2:  Teaching Practical Machine LearningHow to get started today with ML in production: tools, workflows, and mental models.April 10, 2022  · 2 min readHugo Bowne-Anderson
# Fireside chat #1: How to Produce Sustainable Business Value with Machine LearningA fireside chat about product management for ML products across various industries.March 7, 2022  · 2 min readHugo Bowne-Anderson
# Excited to join Metaflow and OuterboundsHugo Bowne-Anderson discussed his journey to becoming Head of Developer Relations at Outerbounds.February 24, 2022  · 8 min readHugo Bowne-Anderson
# Data Scientists Don't Need to Know Kubernetes with MetaflowWith Metaflow, data scientists can leverage K8s clusters for their work. Metaflow presents a user-friendly UX to data scientists, while working nicely with production infrastructure.February 16, 2022  · 5 min readThe Outerbounds Team
# Notebooks in Production with MetaflowLearn how to use notebooks in production ML pipelines with a new Metaflow feature. This is model framework-agnostic and so will work with all types of ML models.February 9, 2022  · 7 min readHamel Husain
# Metaflow Highlights of 2021Developed internally at Netflix and open-sourced in 2019, Metaflow is now used to power machine learning in production by hundreds of companies.January 31, 2022  · 9 min readThe Outerbounds Team
# Integrating Pythonic Visual Reports into ML PipelinesIntroducing DAG cards for machine learning pipelines. These cards make it easy to attach custom visual reports in every workflow, without having to install any additional tooling.January 25, 2022  · 9 min readValay DaveVille Tuulos
# MLOps vs DevOps: the Difference Data MakesA discussion about the machine learning deployment stack and why data makes software different.January 18, 2022  · 6 min readHugo Bowne-Anderson
# Machine Learning Pipelines: from Prototype to ProductionBuild a simple production-ready MLOps pipeline using Metaflow, an OSS framework allowing data scientists to build production-ready machine learning workflows using a simple Python API, and Seldon.January 11, 2022  · 7 min readOleg AvdeevClive Cox

# %%
article = articles[0]

# %%
articles
# Out:
# [<article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/announcing-full-stack-ml-courses/" itemprop="url"><img src="/blog/cover/announcing-full-stack-ml-courses.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/announcing-full-stack-ml-courses/" itemprop="url">Free Live Courses: Full-Stack Machine Learning and Building Systems with LLMs</a></h2><p>Join Hugo Bowne-Anderson for two live courses on building full-stack machine learning systems.</p><time datetime="2024-03-28T01:25:58.000Z" itemprop="datePublished">March 28, 2024<!-- --> <!-- --> · 3 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://outerbounds.com/" rel="noopener noreferrer" target="_blank"><img alt="The Outerbounds Team" class="avatar__photo" src="https://github.com/outerbounds.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://outerbounds.com/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">The Outerbounds Team</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/nvidia-cloud-gpu-announcement/" itemprop="url"><img src="/blog/cover/nvidia-cloud-gpu-announcement.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/nvidia-cloud-gpu-announcement/" itemprop="url">New in Outerbounds: Access NVIDIA Cloud GPUs</a></h2><p>You can now apply to access cloud GPUs directly in NVIDIA's DGX Cloud through Outerbounds - just add @nvidia to access GPUs at scale!</p><time datetime="2024-03-18T03:15:00.000Z" itemprop="datePublished">March 18, 2024<!-- --> <!-- --> · 4 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://outerbounds.com/" rel="noopener noreferrer" target="_blank"><img alt="The Outerbounds Team" class="avatar__photo" src="https://github.com/outerbounds.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://outerbounds.com/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">The Outerbounds Team</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/obp-on-all-clouds/" itemprop="url"><img src="/blog/cover/obp-on-all-clouds.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/obp-on-all-clouds/" itemprop="url">Develop ML/AI systems easily on all clouds</a></h2><p>Outerbounds is now available on all cloud marketplaces. Learn why and how to develop ML/AI systems quickly without cloud lock-in.</p><time datetime="2024-03-15T10:00:00.000Z" itemprop="datePublished">March 15, 2024<!-- --> <!-- --> · 9 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://outerbounds.com/" rel="noopener noreferrer" target="_blank"><img alt="The Outerbounds Team" class="avatar__photo" src="https://github.com/outerbounds.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://outerbounds.com/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">The Outerbounds Team</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/ob-on-the-road-2024-h1/" itemprop="url"><img src="/blog/cover/ob-on-the-road-2024-h1.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/ob-on-the-road-2024-h1/" itemprop="url">Spring Tour 2024</a></h2><p>Outerbounds is going global in 2024. This page shows our event calendar for spring 2024.</p><time datetime="2024-03-12T12:12:00.000Z" itemprop="datePublished">March 12, 2024<!-- --> <!-- --> · 5 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://outerbounds.com/" rel="noopener noreferrer" target="_blank"><img alt="The Outerbounds Team" class="avatar__photo" src="https://github.com/outerbounds.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://outerbounds.com/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">The Outerbounds Team</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/six-steps-to-cost-optimization/" itemprop="url"><img src="/blog/cover/six-steps-to-cost-optimization.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/six-steps-to-cost-optimization/" itemprop="url">The 6 Steps to Cost-Optimized ML/AI/Data Workloads</a></h2><p>We share a six-step process for understanding cloud costs, attributing, and minimizing them. The process is conveniently integrated in the Outerbounds platform.</p><time datetime="2024-02-24T18:20:58.000Z" itemprop="datePublished">February 24, 2024<!-- --> <!-- --> · 10 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://outerbounds.com/" rel="noopener noreferrer" target="_blank"><img alt="The Outerbounds Team" class="avatar__photo" src="https://github.com/outerbounds.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://outerbounds.com/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">The Outerbounds Team</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/the-many-ways-to-deploy-a-model/" itemprop="url"><img src="/blog/cover/the-many-ways-to-deploy-a-model.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/the-many-ways-to-deploy-a-model/" itemprop="url">The Many Ways to Deploy a Model</a></h2><p>There are many ways to deploy models and perform inference. Here, we share our decision rubric for model deployments using LLM inference as an example.</p><time datetime="2024-02-06T09:13:16.000Z" itemprop="datePublished">February 6, 2024<!-- --> <!-- --> · 13 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://hamel.dev" rel="noopener noreferrer" target="_blank"><img alt="Hamel Husain" class="avatar__photo" src="https://github.com/hamelsmu.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://hamel.dev" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">Hamel Husain</span></a></div></div></div><div class="avatar"><a class="avatar__photo-link" href="https://outerbounds.com/" rel="noopener noreferrer" target="_blank"><img alt="The Outerbounds Team" class="avatar__photo" src="https://github.com/outerbounds.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://outerbounds.com/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">The Outerbounds Team</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/pydata-compute-genAI-metaflow/" itemprop="url"><img src="/blog/cover/pydata-global-2023-compute-genai-metaflow-1.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/pydata-compute-genAI-metaflow/" itemprop="url">Generative AI Workflows, Compute, HPC, and Metaflow at PyData Global</a></h2><p>Metaflow and Outerbounds were at PyData Global! We hosted sessions on full stack ML and emphasized discussions on the evolution of the compute layer of the ML stack. This post organizes the presentations in a quick choose-your-own-adventure read.</p><time datetime="2024-02-06T00:52:37.000Z" itemprop="datePublished">February 6, 2024<!-- --> <!-- --> · 8 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://outerbounds.com/" rel="noopener noreferrer" target="_blank"><img alt="The Outerbounds Team" class="avatar__photo" src="https://github.com/outerbounds.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://outerbounds.com/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">The Outerbounds Team</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/metaflow-dynamic-cards/" itemprop="url"><img src="/blog/cover/metaflow-dynamic-cards.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/metaflow-dynamic-cards/" itemprop="url">Metaflow 2.11: Building Observable ML/AI Systems</a></h2><p>Make ML/AI systems observable with new Metaflow Dynamic Cards that provide real-time visualizations.</p><time datetime="2024-01-19T09:00:00.000Z" itemprop="datePublished">January 19, 2024<!-- --> <!-- --> · 8 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://outerbounds.com/" rel="noopener noreferrer" target="_blank"><img alt="The Outerbounds Team" class="avatar__photo" src="https://github.com/outerbounds.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://outerbounds.com/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">The Outerbounds Team</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/metaflow-nvidia-triton/" itemprop="url"><img src="/blog/cover/metaflow-nvidia-triton.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/metaflow-nvidia-triton/" itemprop="url">Develop ML and AI with Metaflow, Deploy with NVIDIA Triton Inference Server</a></h2><p>Learn how Outerbounds and NVIDIA are collaborating to provide an end-to-end system for developing, scaling, deploying, and improving AI systems.</p><time datetime="2024-01-08T10:00:00.000Z" itemprop="datePublished">January 8, 2024<!-- --> <!-- --> · 14 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://outerbounds.com/" rel="noopener noreferrer" target="_blank"><img alt="The Outerbounds Team" class="avatar__photo" src="https://github.com/outerbounds.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://outerbounds.com/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">The Outerbounds Team</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/lights-genai-action/" itemprop="url"><img src="/blog/cover/lights-genai-action.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/lights-genai-action/" itemprop="url">Lights, GenAI, Action: Building Systems with Generative Video</a></h2><p>How to run massively parallel Stable Video Diffusion for production use cases, producing new images and videos automatically in a highly-available manner.</p><time datetime="2023-12-12T06:06:01.000Z" itemprop="datePublished">December 12, 2023  · 10 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://outerbounds.com/" rel="noopener noreferrer" target="_blank"><img alt="The Outerbounds Team" class="avatar__photo" src="https://github.com/outerbounds.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://outerbounds.com/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">The Outerbounds Team</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/making-large-language-models-uncool-again/" itemprop="url"><img src="/blog/cover/making-large-language-models-uncool-again.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/making-large-language-models-uncool-again/" itemprop="url">Making Large Language Models Uncool Again</a></h2><p>We sat down with Jeremy Howard, the creator of fast.ai, to discuss the rapidly evolving AI landscape.</p><time datetime="2023-12-01T05:00:00.000Z" itemprop="datePublished">December 1, 2023  · 13 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://outerbounds.com/" rel="noopener noreferrer" target="_blank"><img alt="The Outerbounds Team" class="avatar__photo" src="https://github.com/outerbounds.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://outerbounds.com/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">The Outerbounds Team</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/ml-at-adept-autodesk-epignosis/" itemprop="url"><img src="/blog/cover/ml-at-adept-autodesk-epignosis.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/ml-at-adept-autodesk-epignosis/" itemprop="url">AI &amp; ML from the Trenches: Adept.ai, Autodesk, and Epignosis – Massive Compute and GenAI</a></h2><p>A summary of recent talks from enterprises building machine learning platforms with Metaflow.</p><time datetime="2023-11-28T12:12:12.000Z" itemprop="datePublished">November 28, 2023  · 10 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://outerbounds.com/" rel="noopener noreferrer" target="_blank"><img alt="The Outerbounds Team" class="avatar__photo" src="https://github.com/outerbounds.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://outerbounds.com/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">The Outerbounds Team</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/distributed-training-with-metaflow/" itemprop="url"><img src="/blog/cover/distributed-training-with-metaflow.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/distributed-training-with-metaflow/" itemprop="url">New in Metaflow: Train at scale with AI/ML frameworks</a></h2><p>Today, we release support for distributed training and other high-performance computing workloads in Metaflow, powered by popular open-source frameworks like Ray, Torch, Deepspeed, Tensorflow and MPI, introduced in this article.</p><time datetime="2023-11-06T06:00:00.000Z" itemprop="datePublished">November 6, 2023  · 12 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://outerbounds.com/" rel="noopener noreferrer" target="_blank"><img alt="The Outerbounds Team" class="avatar__photo" src="https://github.com/outerbounds.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://outerbounds.com/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">The Outerbounds Team</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/compute-with-metaflow/" itemprop="url"><img src="/blog/cover/compute-with-metaflow.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/compute-with-metaflow/" itemprop="url">Compute Anything with Metaflow</a></h2><p>Today, we release support for cost-efficient distributed training and other high-performance computing workloads in Metaflow. Read this post for the backstory.</p><time datetime="2023-11-06T05:00:00.000Z" itemprop="datePublished">November 6, 2023  · 9 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://outerbounds.com/" rel="noopener noreferrer" target="_blank"><img alt="The Outerbounds Team" class="avatar__photo" src="https://github.com/outerbounds.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://outerbounds.com/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">The Outerbounds Team</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/hands-on-llm-rag/" itemprop="url"><img src="/blog/cover/hands-on-llm-rag.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/hands-on-llm-rag/" itemprop="url">LLMs, RAG, and Fine-Tuning: A Hands-On Guided Tour</a></h2><p>A hands-on guided tour to LLMs, prompt engineering, retrieval-augmented generation, and building ML systems in the Metaflow Sandbox.</p><time datetime="2023-11-02T12:23:24.000Z" itemprop="datePublished">November 2, 2023  · 7 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://outerbounds.com/" rel="noopener noreferrer" target="_blank"><img alt="The Outerbounds Team" class="avatar__photo" src="https://github.com/outerbounds.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://outerbounds.com/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">The Outerbounds Team</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/outerbounds-kubecon2023/" itemprop="url"><img src="/blog/cover/outerbounds-kubecon2023.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/outerbounds-kubecon2023/" itemprop="url">Outerbounds at KubeCon NA 2023</a></h2><p>We’re excited to be in Chicago later this month for KubeCon North America.</p><time datetime="2023-10-19T01:00:00.000Z" itemprop="datePublished">October 19, 2023  · 4 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://outerbounds.com/" rel="noopener noreferrer" target="_blank"><img alt="The Outerbounds Team" class="avatar__photo" src="https://github.com/outerbounds.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://outerbounds.com/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">The Outerbounds Team</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/ml-at-amazon-dtn-realtor/" itemprop="url"><img src="/blog/cover/ml-at-amazon-dtn-realtor.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/ml-at-amazon-dtn-realtor/" itemprop="url">AI &amp; ML From the Trenches: Amazon Prime, DTN, and Realtor.com</a></h2><p>A summary of recent talks from enterprises building machine learning platforms with Metaflow.</p><time datetime="2023-10-17T12:12:12.000Z" itemprop="datePublished">October 17, 2023  · 10 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://outerbounds.com/" rel="noopener noreferrer" target="_blank"><img alt="The Outerbounds Team" class="avatar__photo" src="https://github.com/outerbounds.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://outerbounds.com/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">The Outerbounds Team</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/pypi-announcement/" itemprop="url"><img src="/blog/cover/pypi-announcement.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/pypi-announcement/" itemprop="url">New in Metaflow: The Long-Awaited @pypi Decorator</a></h2><p>You can now install dependencies from PyPI as well as Conda in your Metaflow steps.</p><time datetime="2023-10-05T13:02:02.000Z" itemprop="datePublished">October 5, 2023  · 7 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://outerbounds.com/" rel="noopener noreferrer" target="_blank"><img alt="The Outerbounds Team" class="avatar__photo" src="https://github.com/outerbounds.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://outerbounds.com/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">The Outerbounds Team</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/ml-at-deliveryhero-ramp-dell/" itemprop="url"><img src="/blog/cover/ml-at-deliveryhero-ramp-dell.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/ml-at-deliveryhero-ramp-dell/" itemprop="url">AI &amp; ML From the Trenches: DeliveryHero, Ramp, and Dell</a></h2><p>A summary of recent talks from enterprises building machine learning platforms with Metaflow.</p><time datetime="2023-09-21T18:12:10.000Z" itemprop="datePublished">September 21, 2023  · 7 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://outerbounds.com/" rel="noopener noreferrer" target="_blank"><img alt="The Outerbounds Team" class="avatar__photo" src="https://github.com/outerbounds.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://outerbounds.com/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">The Outerbounds Team</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/better-faster-stronger-fine-tuning/" itemprop="url"><img src="/blog/cover/better-faster-stronger-fine-tuning.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/better-faster-stronger-fine-tuning/" itemprop="url">Better, Faster, Stronger LLM Fine-tuning</a></h2><p>Reactive, configurable, cheaper LLM fine-tuning with Metaflow</p><time datetime="2023-09-08T10:13:13.000Z" itemprop="datePublished">September 8, 2023  · 8 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://www.linkedin.com/in/valay-dave-a3588596/" rel="noopener noreferrer" target="_blank"><img alt="Valay Dave" class="avatar__photo" src="https://github.com/valaydave.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://www.linkedin.com/in/valay-dave-a3588596/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">Valay Dave</span></a></div></div></div><div class="avatar"><a class="avatar__photo-link" href="https://www.linkedin.com/in/utkarsh-kashyap-1417a2114/" rel="noopener noreferrer" target="_blank"><img alt="Utkarsh Kashyap" class="avatar__photo" src="/assets/images/UK_headshot-be8933f3ecdbfbe110e13498b925b8cb.jpeg"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://www.linkedin.com/in/utkarsh-kashyap-1417a2114/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">Utkarsh Kashyap</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/retrieval-augmented-generation/" itemprop="url"><img src="/blog/cover/retrieval-augmented-generation.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/retrieval-augmented-generation/" itemprop="url">Retrieval-Augmented Generation: How to Use Your Data to Guide LLMs</a></h2><p>Learn how to use Retrieval Augmented Generation to control hallucinations and get more relevant responses from LLMs.</p><time datetime="2023-08-24T16:00:26.000Z" itemprop="datePublished">August 24, 2023  · 13 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://federicobianchi.io/" rel="noopener noreferrer" target="_blank"><img alt="Federico Bianchi" class="avatar__photo" src="https://github.com/vinid.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://federicobianchi.io/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">Federico Bianchi</span></a></div></div></div><div class="avatar"><a class="avatar__photo-link" href="https://www.linkedin.com/in/eddie-mattia-68ab2984/" rel="noopener noreferrer" target="_blank"><img alt="Eddie Mattia" class="avatar__photo" src="https://github.com/emattia.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://www.linkedin.com/in/eddie-mattia-68ab2984/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">Eddie Mattia</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/seamless-data-pipelines-airflow-metaflow/" itemprop="url"><img src="/blog/cover/seamless-data-pipelines-airflow-metaflow.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/seamless-data-pipelines-airflow-metaflow/" itemprop="url">Seamless Data and ML Pipelines with Airflow and Metaflow</a></h2><p>Learn how to develop ML, AI, and data science with Metaflow, deploy alongside existing data pipelines on Airflow.</p><time datetime="2023-08-10T10:00:00.000Z" itemprop="datePublished">August 10, 2023  · 9 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://www.linkedin.com/in/mpgregor/" rel="noopener noreferrer" target="_blank"><img alt="Michael Gregory" class="avatar__photo" src="/assets/images/michael-headshot-47ed9e44bc577d4f761f6f0b1692547d.jpeg"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://www.linkedin.com/in/mpgregor/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">Michael Gregory</span></a></div></div></div><div class="avatar"><a class="avatar__photo-link" href="https://www.linkedin.com/in/valay-dave-a3588596/" rel="noopener noreferrer" target="_blank"><img alt="Valay Dave" class="avatar__photo" src="https://github.com/valaydave.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://www.linkedin.com/in/valay-dave-a3588596/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">Valay Dave</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/secure-ml-secure-software-dependencies/" itemprop="url"><img src="/blog/cover/secure-ml-secure-software-dependencies.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/secure-ml-secure-software-dependencies/" itemprop="url">Secure ML with Secure Software Dependencies</a></h2><p>Engineers from Chainguard and Outerbunds discuss their common philosophy around security and machine learning workflows.</p><time datetime="2023-07-27T12:00:00.000Z" itemprop="datePublished">July 27, 2023  · 9 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://scholar.google.com/citations?user=c3N1v6kAAAAJ&amp;hl=en" rel="noopener noreferrer" target="_blank"><img alt="Zack Newman" class="avatar__photo" src="/assets/images/zack-headshot-d186bd978acb8179a383b97995edae2d.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://scholar.google.com/citations?user=c3N1v6kAAAAJ&amp;hl=en" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">Zack Newman</span></a></div></div></div><div class="avatar"><a class="avatar__photo-link" href="https://www.linkedin.com/in/savingoyal/" rel="noopener noreferrer" target="_blank"><img alt="Savin Goyal" class="avatar__photo" src="https://github.com/savingoyal.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://www.linkedin.com/in/savingoyal/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">Savin Goyal</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/obp-release-july-2023/" itemprop="url"><img src="/blog/cover/workstations-announcement.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/obp-release-july-2023/" itemprop="url">Announcing 4 New Features in the Outerbounds Platform: Cloud Workstations and More</a></h2><p>Explore four major new features in the Outerbounds Platform</p><time datetime="2023-07-19T12:00:00.000Z" itemprop="datePublished">July 19, 2023  · 10 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://outerbounds.com/" rel="noopener noreferrer" target="_blank"><img alt="The Outerbounds Team" class="avatar__photo" src="https://github.com/outerbounds.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://outerbounds.com/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">The Outerbounds Team</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/learn-full-stack-ml-corise/" itemprop="url"><img src="/blog/cover/learn-full-stack-ml-corise.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/learn-full-stack-ml-corise/" itemprop="url">Learn Full-Stack Machine Learning: Batteries Included</a></h2><p>Learn how you can get started with full-stack ML today in a hands-on, project-driven course using production-grade ML systems.</p><time datetime="2023-07-10T12:40:26.000Z" itemprop="datePublished">July 10, 2023  · 7 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://www.linkedin.com/in/hugo-bowne-anderson-045939a5/" rel="noopener noreferrer" target="_blank"><img alt="Hugo Bowne-Anderson" class="avatar__photo" src="https://github.com/hugobowne.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://www.linkedin.com/in/hugo-bowne-anderson-045939a5/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">Hugo Bowne-Anderson</span></a></div></div></div><div class="avatar"><a class="avatar__photo-link" href="https://www.linkedin.com/in/villetuulos/" rel="noopener noreferrer" target="_blank"><img alt="Ville Tuulos" class="avatar__photo" src="https://github.com/tuulos.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://www.linkedin.com/in/villetuulos/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">Ville Tuulos</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/llm-tuning-metaflow/" itemprop="url"><img src="/blog/cover/llm-tuning-metaflow.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/llm-tuning-metaflow/" itemprop="url">Fine-tuning a Large Language Model using Metaflow, featuring LLaMA and LoRA</a></h2><p>A workflow template built with Metaflow for fine-tuning LLMs for custom use cases.</p><time datetime="2023-06-21T12:41:26.000Z" itemprop="datePublished">June 21, 2023  · 16 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://federicobianchi.io/" rel="noopener noreferrer" target="_blank"><img alt="Federico Bianchi" class="avatar__photo" src="https://github.com/vinid.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://federicobianchi.io/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">Federico Bianchi</span></a></div></div></div><div class="avatar"><a class="avatar__photo-link" href="https://outerbounds.com/" rel="noopener noreferrer" target="_blank"><img alt="The Outerbounds Team" class="avatar__photo" src="https://github.com/outerbounds.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://outerbounds.com/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">The Outerbounds Team</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/custom-llm-tuning/" itemprop="url"><img src="/blog/cover/custom-llm-tuning.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/custom-llm-tuning/" itemprop="url">Large Language Models and the Future of Custom, Fine-tuned LLMs</a></h2><p>An overview of instruction tuning for large language models using the LLaMA family of models.</p><time datetime="2023-06-21T12:40:26.000Z" itemprop="datePublished">June 21, 2023  · 16 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://federicobianchi.io/" rel="noopener noreferrer" target="_blank"><img alt="Federico Bianchi" class="avatar__photo" src="https://github.com/vinid.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://federicobianchi.io/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">Federico Bianchi</span></a></div></div></div><div class="avatar"><a class="avatar__photo-link" href="https://outerbounds.com/" rel="noopener noreferrer" target="_blank"><img alt="The Outerbounds Team" class="avatar__photo" src="https://github.com/outerbounds.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://outerbounds.com/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">The Outerbounds Team</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/oss-modern-data-stack-recap/" itemprop="url"><img src="/blog/cover/oss-modern-data-stack-recap.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/oss-modern-data-stack-recap/" itemprop="url">The Open-Source Modern Data Stack featuring Apache Iceberg</a></h2><p>We sat down with Jason Reid, a Co-founder at Tabular, to discuss the Apache Iceberg project and how it fits into the modern data stack.</p><time datetime="2023-06-14T11:13:16.000Z" itemprop="datePublished">June 14, 2023  · 10 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://www.linkedin.com/in/jasonreid/" rel="noopener noreferrer" target="_blank"><img alt="Jason Reid" class="avatar__photo" src="/assets/images/jason_headshot-845ac4bf3d84a55e47f251820b3fd126.jpeg"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://www.linkedin.com/in/jasonreid/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">Jason Reid</span></a></div></div></div><div class="avatar"><a class="avatar__photo-link" href="https://www.linkedin.com/in/hugo-bowne-anderson-045939a5/" rel="noopener noreferrer" target="_blank"><img alt="Hugo Bowne-Anderson" class="avatar__photo" src="https://github.com/hugobowne.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://www.linkedin.com/in/hugo-bowne-anderson-045939a5/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">Hugo Bowne-Anderson</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/metaflow-secrets/" itemprop="url"><img src="/blog/cover/metaflow_secrets.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/metaflow-secrets/" itemprop="url">New in Metaflow: Accessing Secrets Securely</a></h2><p>You can now access secrets securely in Metaflow flows using the new secrets decorator.</p><time datetime="2023-06-02T19:08:08.000Z" itemprop="datePublished">June 2, 2023  · 4 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://outerbounds.com/" rel="noopener noreferrer" target="_blank"><img alt="The Outerbounds Team" class="avatar__photo" src="https://github.com/outerbounds.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://outerbounds.com/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">The Outerbounds Team</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/metaflow-event-triggering/" itemprop="url"><img src="/blog/cover/metaflow-event-triggering.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/metaflow-event-triggering/" itemprop="url">Metaflow 2.9: Building Reactive Machine Learning Systems with Event Triggering</a></h2><p>Using the new event triggering feature in Metaflow, you can compose systems using workflows as building blocks and trigger them based on external events.</p><time datetime="2023-05-17T15:13:16.000Z" itemprop="datePublished">May 17, 2023  · 8 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://outerbounds.com/" rel="noopener noreferrer" target="_blank"><img alt="The Outerbounds Team" class="avatar__photo" src="https://github.com/outerbounds.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://outerbounds.com/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">The Outerbounds Team</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/llm-value-and-risk/" itemprop="url"><img src="/blog/cover/llm-value-and-risk.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/llm-value-and-risk/" itemprop="url">Large Language Models, Business Value, and Risk</a></h2><p>An interview with Federico Bianchi, a postdoctoral NLP researcher at Stanford exploring the boundaries of large language models.</p><time datetime="2023-05-11T12:00:21.000Z" itemprop="datePublished">May 11, 2023  · 15 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://federicobianchi.io/" rel="noopener noreferrer" target="_blank"><img alt="Federico Bianchi" class="avatar__photo" src="https://github.com/vinid.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://federicobianchi.io/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">Federico Bianchi</span></a></div></div></div><div class="avatar"><a class="avatar__photo-link" href="https://www.linkedin.com/in/hugo-bowne-anderson-045939a5/" rel="noopener noreferrer" target="_blank"><img alt="Hugo Bowne-Anderson" class="avatar__photo" src="https://github.com/hugobowne.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://www.linkedin.com/in/hugo-bowne-anderson-045939a5/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">Hugo Bowne-Anderson</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/metaflow-fast-data/" itemprop="url"><img src="/blog/cover/metaflow-fast-data.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/metaflow-fast-data/" itemprop="url">Fast Data: Loading Tables From S3 At Lightning Speed</a></h2><p>Load and process tabular data at lightning speed using Apache Arrow and Metaflow.</p><time datetime="2023-05-05T20:13:16.000Z" itemprop="datePublished">May 5, 2023  · 11 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://outerbounds.com/" rel="noopener noreferrer" target="_blank"><img alt="The Outerbounds Team" class="avatar__photo" src="https://github.com/outerbounds.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://outerbounds.com/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">The Outerbounds Team</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/mlops-real-estate/" itemprop="url"><img src="/blog/cover/mlops-real-estate.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/mlops-real-estate/" itemprop="url">Case Study: How Realtor.com uses Metaflow</a></h2><p>We sat down with Russell Brooks, Principal ML Engineer at Realtor.com, to discuss how his team uses Metaflow, and how it impacts Realtor.com.</p><time datetime="2023-04-26T20:13:16.000Z" itemprop="datePublished">April 26, 2023  · 12 min read</time></div><div class="authors_Co8h"><div class="avatar"><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://www.linkedin.com/in/russellabrooks/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">Russell Brooks</span></a></div></div></div><div class="avatar"><a class="avatar__photo-link" href="https://www.linkedin.com/in/hugo-bowne-anderson-045939a5/" rel="noopener noreferrer" target="_blank"><img alt="Hugo Bowne-Anderson" class="avatar__photo" src="https://github.com/hugobowne.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://www.linkedin.com/in/hugo-bowne-anderson-045939a5/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">Hugo Bowne-Anderson</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/train-dolly-metaflow/" itemprop="url"><img src="/blog/cover/train-dolly-metaflow.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/train-dolly-metaflow/" itemprop="url">Training a Large Language Model With Metaflow, Featuring Dolly</a></h2><p>We use Metaflow to train Dolly, to show an example of fine-tuning LLMs and what it takes to use these models in practice.</p><time datetime="2023-04-20T15:55:09.000Z" itemprop="datePublished">April 20, 2023  · 12 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://outerbounds.com/" rel="noopener noreferrer" target="_blank"><img alt="The Outerbounds Team" class="avatar__photo" src="https://github.com/outerbounds.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://outerbounds.com/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">The Outerbounds Team</span></a></div></div></div></div></div></header></article>,
# ...
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/the-modern-stack-of-ml-infrastructure/" itemprop="url"><img src="/blog/cover/the-modern-stack-of-ml-infrastructure.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/the-modern-stack-of-ml-infrastructure/" itemprop="url">The Modern Stack of ML Infrastructure</a></h2><p>A discussion about the machine learning deployment stack and why data makes software different.</p><time datetime="2022-05-02T05:24:03.000Z" itemprop="datePublished">May 2, 2022  · 9 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://www.linkedin.com/in/villetuulos/" rel="noopener noreferrer" target="_blank"><img alt="Ville Tuulos" class="avatar__photo" src="https://github.com/tuulos.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://www.linkedin.com/in/villetuulos/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">Ville Tuulos</span></a></div></div></div><div class="avatar"><a class="avatar__photo-link" href="https://www.linkedin.com/in/hugo-bowne-anderson-045939a5/" rel="noopener noreferrer" target="_blank"><img alt="Hugo Bowne-Anderson" class="avatar__photo" src="https://github.com/hugobowne.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://www.linkedin.com/in/hugo-bowne-anderson-045939a5/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">Hugo Bowne-Anderson</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/human-centric-data-science-on-kubernetes-with-metaflow/" itemprop="url"><img src="/blog/cover/human-centric-data-science-on-kubernetes-with-metaflow.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/human-centric-data-science-on-kubernetes-with-metaflow/" itemprop="url">Human-Centric Data Science on Kubernetes with Metaflow</a></h2><p>Data scientists can now scale out their machine learning workflows to Kubernetes clusters using Metaflow and Argo, without needing to know the ins and outs of K8S.</p><time datetime="2022-04-25T02:11:09.000Z" itemprop="datePublished">April 25, 2022  · 8 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://www.linkedin.com/in/savingoyal/" rel="noopener noreferrer" target="_blank"><img alt="Savin Goyal" class="avatar__photo" src="https://github.com/savingoyal.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://www.linkedin.com/in/savingoyal/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">Savin Goyal</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/fireside-chat-2-madewithml-com-teaching-practical-machine-learning/" itemprop="url"><img src="/blog/cover/fireside-chat-2-madewithml-com-teaching-practical-machine-learning.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/fireside-chat-2-madewithml-com-teaching-practical-machine-learning/" itemprop="url">Fireside chat #2:  Teaching Practical Machine Learning</a></h2><p>How to get started today with ML in production: tools, workflows, and mental models.</p><time datetime="2022-04-10T04:49:00.000Z" itemprop="datePublished">April 10, 2022  · 2 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://www.linkedin.com/in/hugo-bowne-anderson-045939a5/" rel="noopener noreferrer" target="_blank"><img alt="Hugo Bowne-Anderson" class="avatar__photo" src="https://github.com/hugobowne.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://www.linkedin.com/in/hugo-bowne-anderson-045939a5/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">Hugo Bowne-Anderson</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/fireside-chat-1-how-to-produce-sustainable-business-value-with-machinelearning/" itemprop="url"><img src="/blog/cover/fireside-chat-1-how-to-produce-sustainable-business-value-with-machinelearning.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/fireside-chat-1-how-to-produce-sustainable-business-value-with-machinelearning/" itemprop="url">Fireside chat #1: How to Produce Sustainable Business Value with Machine Learning</a></h2><p>A fireside chat about product management for ML products across various industries.</p><time datetime="2022-03-07T04:53:00.000Z" itemprop="datePublished">March 7, 2022  · 2 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://www.linkedin.com/in/hugo-bowne-anderson-045939a5/" rel="noopener noreferrer" target="_blank"><img alt="Hugo Bowne-Anderson" class="avatar__photo" src="https://github.com/hugobowne.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://www.linkedin.com/in/hugo-bowne-anderson-045939a5/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">Hugo Bowne-Anderson</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/hba-excited-to-join-metaflow-and-outerbounds/" itemprop="url"><img src="/blog/cover/hba-excited-to-join-metaflow-and-outerbounds.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/hba-excited-to-join-metaflow-and-outerbounds/" itemprop="url">Excited to join Metaflow and Outerbounds</a></h2><p>Hugo Bowne-Anderson discussed his journey to becoming Head of Developer Relations at Outerbounds.</p><time datetime="2022-02-24T02:18:32.000Z" itemprop="datePublished">February 24, 2022  · 8 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://www.linkedin.com/in/hugo-bowne-anderson-045939a5/" rel="noopener noreferrer" target="_blank"><img alt="Hugo Bowne-Anderson" class="avatar__photo" src="https://github.com/hugobowne.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://www.linkedin.com/in/hugo-bowne-anderson-045939a5/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">Hugo Bowne-Anderson</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/kubernetes-to-metaflow/" itemprop="url"><img src="/blog/cover/kubernetes-to-metaflow.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/kubernetes-to-metaflow/" itemprop="url">Data Scientists Don't Need to Know Kubernetes with Metaflow</a></h2><p>With Metaflow, data scientists can leverage K8s clusters for their work. Metaflow presents a user-friendly UX to data scientists, while working nicely with production infrastructure.</p><time datetime="2022-02-16T03:23:24.000Z" itemprop="datePublished">February 16, 2022  · 5 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://outerbounds.com/" rel="noopener noreferrer" target="_blank"><img alt="The Outerbounds Team" class="avatar__photo" src="https://github.com/outerbounds.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://outerbounds.com/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">The Outerbounds Team</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/notebooks-in-production-with-metaflow/" itemprop="url"><img src="/blog/cover/notebooks-in-production-with-metaflow.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/notebooks-in-production-with-metaflow/" itemprop="url">Notebooks in Production with Metaflow</a></h2><p>Learn how to use notebooks in production ML pipelines with a new Metaflow feature. This is model framework-agnostic and so will work with all types of ML models.</p><time datetime="2022-02-09T22:59:06.000Z" itemprop="datePublished">February 9, 2022  · 7 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://hamel.dev" rel="noopener noreferrer" target="_blank"><img alt="Hamel Husain" class="avatar__photo" src="https://github.com/hamelsmu.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://hamel.dev" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">Hamel Husain</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/metaflow-highlights-2021/" itemprop="url"><img src="/blog/cover/metaflow-highlights-2021.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/metaflow-highlights-2021/" itemprop="url">Metaflow Highlights of 2021</a></h2><p>Developed internally at Netflix and open-sourced in 2019, Metaflow is now used to power machine learning in production by hundreds of companies.</p><time datetime="2022-01-31T03:35:00.000Z" itemprop="datePublished">January 31, 2022  · 9 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://outerbounds.com/" rel="noopener noreferrer" target="_blank"><img alt="The Outerbounds Team" class="avatar__photo" src="https://github.com/outerbounds.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://outerbounds.com/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">The Outerbounds Team</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/integrating-pythonic-visual-reports-into-ml-pipelines/" itemprop="url"><img src="/blog/cover/integrating-pythonic-visual-reports-into-ml-pipelines.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/integrating-pythonic-visual-reports-into-ml-pipelines/" itemprop="url">Integrating Pythonic Visual Reports into ML Pipelines</a></h2><p>Introducing DAG cards for machine learning pipelines. These cards make it easy to attach custom visual reports in every workflow, without having to install any additional tooling.</p><time datetime="2022-01-25T00:03:21.000Z" itemprop="datePublished">January 25, 2022  · 9 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://www.linkedin.com/in/valay-dave-a3588596/" rel="noopener noreferrer" target="_blank"><img alt="Valay Dave" class="avatar__photo" src="https://github.com/valaydave.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://www.linkedin.com/in/valay-dave-a3588596/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">Valay Dave</span></a></div></div></div><div class="avatar"><a class="avatar__photo-link" href="https://www.linkedin.com/in/villetuulos/" rel="noopener noreferrer" target="_blank"><img alt="Ville Tuulos" class="avatar__photo" src="https://github.com/tuulos.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://www.linkedin.com/in/villetuulos/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">Ville Tuulos</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/mlops-vs-devops/" itemprop="url"><img src="/blog/cover/mlops-vs-devops.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/mlops-vs-devops/" itemprop="url">MLOps vs DevOps: the Difference Data Makes</a></h2><p>A discussion about the machine learning deployment stack and why data makes software different.</p><time datetime="2022-01-18T00:26:09.000Z" itemprop="datePublished">January 18, 2022  · 6 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://www.linkedin.com/in/hugo-bowne-anderson-045939a5/" rel="noopener noreferrer" target="_blank"><img alt="Hugo Bowne-Anderson" class="avatar__photo" src="https://github.com/hugobowne.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://www.linkedin.com/in/hugo-bowne-anderson-045939a5/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">Hugo Bowne-Anderson</span></a></div></div></div></div></div></header></article>,
#  <article itemprop="blogPost" itemscope="" itemtype="http://schema.org/BlogPosting"><header class="header_slCM"><a href="/blog/machine-learning-pipelines-from-prototype-to-production/" itemprop="url"><img src="/blog/cover/machine-learning-pipelines-from-prototype-to-production.jpg"/></a><div class="headerContent_JF9x"><div><h2 itemprop="headline"><a href="/blog/machine-learning-pipelines-from-prototype-to-production/" itemprop="url">Machine Learning Pipelines: from Prototype to Production</a></h2><p>Build a simple production-ready MLOps pipeline using Metaflow, an OSS framework allowing data scientists to build production-ready machine learning workflows using a simple Python API, and Seldon.</p><time datetime="2022-01-11T00:31:21.000Z" itemprop="datePublished">January 11, 2022  · 7 min read</time></div><div class="authors_Co8h"><div class="avatar"><a class="avatar__photo-link" href="https://www.linkedin.com/in/oavdeev/" rel="noopener noreferrer" target="_blank"><img alt="Oleg Avdeev" class="avatar__photo" src="https://github.com/oavdeev.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://www.linkedin.com/in/oavdeev/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">Oleg Avdeev</span></a></div></div></div><div class="avatar"><a class="avatar__photo-link" href="https://www.linkedin.com/in/clive-cox-8641922/" rel="noopener noreferrer" target="_blank"><img alt="Clive Cox" class="avatar__photo" src="https://github.com/cliveseldon.png"/></a><div class="avatar__intro" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatar__name"><a href="https://www.linkedin.com/in/clive-cox-8641922/" itemprop="url" rel="noopener noreferrer" target="_blank"><span itemprop="name">Clive Cox</span></a></div></div></div></div></div></header></article>]

# %%
urls = []
for article in articles:
    urls.append("https://outerbounds.com" + article.find('a')['href'])

# %%
len(urls)
# Out:
# 75

# %%
urls[0]
# Out:
# 'https://outerbounds.com/blog/announcing-full-stack-ml-courses/'

# %%
loader = WebBaseLoader(urls[:5])
docs = loader.load()

# %%
print(docs[0])
# Out:
# page_content='\n\n\n\n\nFree Live Courses: Full-Stack Machine Learning and Building Systems with LLMs | Outerbounds\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to main contentOuterboundsTry Metaflow SandboxStart for FreeOuterboundsPlatformMetaflowPricingResourcesData ScienceEngineeringMoreBlogAbout UsCareersSlackGithubYouTube← Back to main menuBlogFree Live Courses: Full-Stack Machine Learning and Building Systems with LLMsNews and UpdatesCommunityBest PracticesMarch 28, 2024  · 3 min readThe Outerbounds TeamFollowing the popular hands-on courses and workshops that we taught last year at SciPy, ODSC, and Uplimit, today we are announcing two new live courses that you can join online for free!The courses are taught by Hugo Bowne-Anderson whose courses on DataCamp and other platforms have been followed by over 4 million learners worldwide. The space is limited, so sign up to one or both of the courses below!Course 1: Full-Stack Machine Learning with MetaflowIn this course, you’ll learn how to\u200bOrchestrate machine learning workflows,Use versioning, model reporting, and notebooks to inspect your workflows and models,Leverage cloud compute resources to scale entire workflows and single steps,Deploy workflows and models to production systems, andConfigure A/B tests to establish iterative AI development cycles.Join this course if you know Python, have some background in ML and data science, and you want to learn how to build real-life, production-grade ML systems.You will be able to hone your skills with a full stack of ML infrastructure using our sandbox environment, a browser-based VSCode environment powered by open-source Metaflow, so you don’t need to install anything locally. You can focus on building applications, not configuring infrastructure, as one of our previous students, Emily Ekdahl from Vouch Insurance observed:“One standout feature of the class was the efficient use of Metaflow sandboxes to streamline the environment setup. This approach allowed participants to focus on learning rather than getting bogged down in complex configuration processes."The best part is that you can deploy the same stack in your own environment after the course, following the footsteps of hundreds of other sophisticated ML organizations.Course 2: LLMs, RAG, and Fine-Tuning: A Hands-On Guided TourIf you are interested in learning about building systems powered by Generative AI and Large Language Models, join this course! This course is based on a well-received workshop we taught at Generative AI World last fall.You will learn how to\u200bVarious proprietary off-the-shelf models and APIs,Open-source LLMs,Prompt engineering,The Retrieval Augment Generation (RAG) pattern,\u200bVector databases, andBuilding a constantly updating production RAG system with Metaflow.We will give an overview of these techniques. If you know the basics already, this course will teach how to build actual systems powered by GenAI, going beyond the usual notebooks demos.This course will leverage our sandbox environment similar to the first course, so you don’t need to install anything locally.Join the courses today by clicking the images below!Tags:infrastructuremachine learningplatformSmarter machines, built by happier\xa0humansThe future will be powered by dynamic, data intensive systems - built by happy humans using tooling that gives them superpowersGet started for free OuterboundsA human-centric platform for all ML, AI, and data apps.PlatformOverviewDevelopVersion & trackFriendly APICloud workstationsScaleUse GPUs for AICompute at scaleAccess dataDeployProduction flowsExperiment safelyRunSecurity & complianceFully managed SLAMetaflowOpen-SourceSandboxCommunityResourcesData ScienceWelcomeSandboxTutorialsHow-To-GuidesEngineeringWelcomeDeploymentOperationsMoreEventsSuccess StoriesPricingBlogAbout UsCareers©\xa0Outerbounds, 2024Privacy PolicyTerms of Use\n\n\n\n' metadata={'source': 'https://outerbounds.com/blog/announcing-full-stack-ml-courses/', 'title': 'Free Live Courses:  ...

# %% [markdown]
# # Load sitemap

# %%
sitemap='https://outerbounds.com/sitemap.xml'

# %%
response = requests.get(sitemap)

# %%
sitemap_content = response.content
root = ET.fromstring(sitemap_content)
namespaces = {'ns': 'http://www.sitemaps.org/schemas/sitemap/0.9'}
urls=[]
for url in root.findall('ns:url/ns:loc', namespaces=namespaces):
    if 'blog' in url.text or 'docs' in url.text or 'engineering' in url.text:
        urls.append(url.text)

# %%
FIELDS = ['title', 'content', 'url', 'date', 'author', 'tags', 'canonical', 'alternate', 'description']

# %%
data = {field: [] for field in FIELDS}
for url in tqdm(urls):
    page_response = requests.get(url)
    page_content = page_response.content
    soup = BeautifulSoup(page_content, 'html.parser')
    head = soup.find('head')

    try:
        title = head.find('meta', attrs={"property": "og:title"}).get('content')
    except AttributeError:
        raise ValueError(f"og:title not found for {url}")
    try:
        description = head.find('meta', attrs={"property": "og:description"}).get('content')
    except AttributeError:
        raise ValueError(f"og:title not found for {url}")

    canonical = head.find('link', {'rel': 'canonical'})['href']
    alternate = head.find('link', {'rel': 'alternate'})['href']

    if 'blog' in url: 
        content = str(soup.find('div', id="post-content", class_="markdown firstLetter__Rps"))
        if content == 'None':
            content = pd.NA
        try:
            tags = head.find('meta', attrs={"property": "article:tag"}).get('content')
        except AttributeError:
            tags = pd.NA
        try:
            author = head.find('meta', attrs={"property": "article:author"}).get('content')
        except:
            author = pd.NA
        try:
            publish_date = head.find('meta', attrs={"property": "article:published_time"}).get('content')
        except:
            publish_date = pd.NA
    elif 'docs' in url or 'engineering' in url:
        content = str(soup.find('div', id="docMainContainer_gTbr"))
        if content == 'None':
            content = str(soup.find('main')) #, id="docMainContainer_gTbr"))
        if content == 'None':
            raise ValueError(f"docMainContainer_gTbr not found for {url}")
        tags = ','.join([a_tag.text for a_tag in soup.find_all('a', class_="tag_zVej tagRegular_sFm0")])
        author = pd.NA
        publish_date = pd.NA

    data['title'].append(title)
    data['content'].append(content)
    data['description'].append(description)
    data['url'].append(url)
    data['date'].append(publish_date)
    data['author'].append(author)
    data['canonical'].append(canonical)
    data['alternate'].append(alternate)
    data['tags'].append(tags)
# Out:
# 100%|██████████| 216/216 [00:22<00:00,  9.55it/s]

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#                                                title  \
# 0        Building the ML-driven future | Outerbounds
# 1  Free Live Courses: Full-Stack Machine Learning...
# 2  Announcing the Metaflow Card Viewer | Outerbounds
# 3  Announcing The Outerbounds Platform | Outerbounds
# 4        Building the ML-driven future | Outerbounds
#
#                                              content  \
# 0                                               <NA>
# 1  <div class="markdown firstLetter__Rps" id="pos...
# 2  <div class="markdown firstLetter__Rps" id="pos...
# 3  <div class="markdown firstLetter__Rps" id="pos...
# 4                                               <NA>
#
#                                                  url  \
# 0                      https://outerbounds.com/blog/
# 1  https://outerbounds.com/blog/announcing-full-s...
# 2  https://outerbounds.com/blog/announcing-metafl...
# 3  https://outerbounds.com/blog/announcing-outerb...
# 4              https://outerbounds.com/blog/archive/
#
#                        date                    author  \
# 0                      <NA>                      <NA>
# 1  2024-03-28T01:25:58.000Z  https://outerbounds.com/
# 2  2023-04-13T19:08:08.000Z  https://outerbounds.com/
# 3  2023-01-31T13:25:58.000Z  https://outerbounds.com/
# 4                      <NA>                      <NA>
#
#                                           tags  \
# 0                                         <NA>
# 1     infrastructure,machine learning,platform
# 2  sandbox,machine learning,data visualization
# 3     infrastructure,machine learning,platform
# 4                                         <NA>
#
#                                            canonical  \
# 0                      https://outerbounds.com/blog/
# 1  https://outerbounds.com/blog/announcing-full-s...
# 2  https://outerbounds.com/blog/announcing-metafl...
# 3  https://outerbounds.com/blog/announcing-outerb...
# 4                      https://outerbounds.com/blog/
#
#                                            alternate
# 0                      https://outerbounds.com/blog/
# 1  https://outerbounds.com/blog/announcing-full-s...
# 2  https://outerbounds.com/blog/announcing-metafl...
# 3  https://outerbounds.com/blog/announcing-outerb...
# 4                      https://outerbounds.com/blog/

# %%
df.content.isna().sum()
# Out:
# 2

# %%
df[df.content.isna()].url.values
# Out:
# array(['https://outerbounds.com/blog/',
#        'https://outerbounds.com/blog/archive/'], dtype=object)

# %%
df.content.sample(5)
# Out:
# 12     <div class="markdown firstLetter__Rps" id="pos...
# 181    <main class="docMainContainer_gTbr"><div class...
# 92     <main class="docMainContainer_gTbr"><div class...
# 106    <main class="docMainContainer_gTbr"><div class...
# 83     <main class="docMainContainer_gTbr"><div class...
# Name: content, dtype: object

# %%
sample = df.content.sample(1).values[0]

# %%
from IPython.core.display import display, HTML
display(HTML(sample))
# Out:
# /var/folders/rl/z6mhck6x3h1bl5bjmn0y3ws80000gn/T/ipykernel_39811/2915790267.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <div class="markdown firstLetter__Rps" id="post-content" itemprop="articleBody"><p>We recently sat down with Jules Belveze, an MLOps Engineer at <a href="https://hypefactors.com/" rel="noopener noreferrer" target="_blank">Hypefactors</a> where they apply NLP and AI for media intelligence, to discuss how his team uses Metaflow, among many other great tools, and how it has impacted machine learning more generally at Hypefactors.</p><h2 class="anchor anchorWithStickyNavbar_LWe7" id="what-type-of-ml-questions-do-you-work-on-at-hypefactors-and-what-type-of-business-questions-do-they-solve">What type of ML questions do you work on at Hypefactors and what type of business questions do they solve?<a aria-label="Direct link to What type of ML questions do you work on at Hypefactors and what type of business questions do they solve?" class="hash-link" href="#what-type-of-ml-questions-do-you-work-on-at-hypefactors-and-what-type-of-business-questions-do-they-solve" title="Direct link to What type of ML questions do you work on at Hypefactors and what type of business questions do they solve?">​</a></h2><p>At Hypefactors we apply AI for media intelligence. We leverage AI-based automation to derive and massively scale the real-time insights from the ongoing media landscape and handle the increasing volume of data.</p><p>We have a plethora of models, ranging from transformer-based NLP, computer vision, statistical models, and automated reasoning models. In terms of NLP, we do tasks ranging from sequence classification to text generation and span classification tasks.</p><p>All those models enable us to digest the media landscape in real-time and extract information for our clients. Some of our models, for example, our <a href="https://hypefactors.com/blog/noi-names-of-interest-teknologien-tager-hypefactors-media-intelligence-losning-til-et-for-uset-niveau-for-praecision/" rel="noopener noreferrer" target="_blank">named-entity recognition model,</a> are fundamental to powering our use cases. Our approach is to scale the AIs to comprehend hundreds of languages that are in use in the media. This allows us to cover and monitor a vast range of media sources from all corners of the world, which would be intractable without AI.</p><h2 class="anchor anchorWithStickyNavbar_LWe7" id="what-did-your-ml-stack-look-like-before-you-adopted-metaflow-and-what-pain-points-did-you-encounter">What did your ML stack look like before you adopted Metaflow and what pain points did you encounter?<a aria-label="Direct link to What did your ML stack look like before you adopted Metaflow and what pain points did you encounter?" class="hash-link" href="#what-did-your-ml-stack-look-like-before-you-adopted-metaflow-and-what-pain-points-did-you-encounter" title="Direct link to What did your ML stack look like before you adopted Metaflow and what pain points did you encounter?">​</a></h2><p>I would first split our tool stack into 4 components: data, modeling, testing, optimization, and inference.</p><p>On the data part, we typically use <a href="https://labelstud.io/" rel="noopener noreferrer" target="_blank">Label Studio</a> for data annotation and an in-house tool called “bundler” for label QA and exploration. We then version our experiments and associated data using <a href="https://neptune.ai/" rel="noopener noreferrer" target="_blank">Neptune.ai</a> and another in-house tool.</p><p>Regarding model development, we use a combination of <a href="https://www.pytorchlightning.ai/" rel="noopener noreferrer" target="_blank">PyTorch Lightning</a> and the <a href="https://huggingface.co/docs" rel="noopener noreferrer" target="_blank">Hugging Face ecosystem</a>. <a href="https://hydra.cc/docs/intro/" rel="noopener noreferrer" target="_blank">Hydra</a> enables us to experiment with different configurations faster and is also used along with Neptune for experiment tracking.</p><p>Once we are satisfied with the trained models we go on and validate them. We have several tools at our ...
